# %% [markdown]
# # **Make Pretrained-Model FaceNet !**

# %% [markdown]
# ## 0.미션

# %% [markdown]
# ### (1) 미션1
# 여러분은 노트북에서 얼굴 인식 파일을 실행시키기 위해 사전 학습 모델을 만들어야 합니다.
#
# 그 전에 가지고 있는 데이터셋을 **학습에 적합한 형태**로 만들어야 합니다.
#
# - 1) 데이터셋을 불러옵니다.
#     - 데이터셋은 2가지입니다. 본인의 얼굴 이미지 파일, 다른 사람의 얼굴 이미지 파일.
# - 2) 데이터셋을 전처리합니다.
#     - Keras에는 **실제로 존재하는 이미지 데이터를 처리**해주는 함수가 있습니다.

# %% [markdown]
# ### (2) 미션2
# 데이터셋을 **학습에 적합한 형태**로 만들었다면, **FaceNet 모델로 Transfer Learning**을 수행합니다.
#
# - 1) FaceNet 모델 구조를 생성합니다.
#     - [FaceNet 논문 링크](https://arxiv.org/abs/1503.03832)
#     - FaceNet의 Input은 (160, 160) 사이즈의 이미지입니다.
# - 2) FaceNet 모델 구조 + 구조 추가
#     - FaceNet의 Output은 128차원의 벡터입니다.
#     - 이 과정을 Transfer Learning라고 합니다.

# %% [markdown]
# ### (3) 미션3
# 학습된 모델로 추론하여 성능 지표를 확인하고 모델을 개선시키세요.
#
# 그 후, 모델의 구조와 가중치를 **반드시 저장**하여 여러분의 노트북에 옮기세요.
#
# - 1) 다양한 모델을 사용해보세요.
#     - 모델에 정해진 정답은 없습니다.
#     - 성능 지표에서 무엇이 중요한지 깊게 생각하세요.
#     - 사전 학습된 FaceNet 모델을 사용하셔도 좋고, 아예 독창적으로 여러분만의 모델을 만드셔도 좋습니다!
# - 2) 모델을 **반드시 저장**하세요.
#     - .keras 형태로 우선 Colab에 저장하세요.
#     - Colab에 생성된 .keras 파일을 **로컬에 다운로드** 합니다.

# %% [markdown]
# ## 1.환경설정

# %% [markdown]
# * 세부 요구사항
#     - 경로 설정 : 구글콜랩
#         * 구글 드라이브 바로 밑에 project4 폴더를 만드세요.
#         * 데이터 파일을 복사해 넣습니다.
#         * 필요하다고 판단되는 라이브러리를 추가하세요.

# %% [markdown]
# ### (1) 경로 설정

# %% [markdown]
# * 구글 드라이브 연결

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/project4'

# %% [markdown]
# ### (2) 라이브러리 설치 및 불러오기

# %% [markdown]
# * 라이브러리 로딩

# %%
## colab에서 세션 재시작을 요구하는 팝업이 뜨면 재시작 누르세요.
# !pip install keras-nightly
# Out:
# Collecting keras-nightly
#   Downloading keras_nightly-3.7.0.dev2024110706-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras-nightly) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras-nightly) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras-nightly) (13.9.3)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras-nightly) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-nightly) (3.12.1)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras-nightly) (0.13.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras-nightly) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-nightly) (24.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras-nightly) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-nightly) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-nightly) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras-nightly) (0.1.2)
# Downloading keras_nightly-3.7.0.dev2024110706-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 23.6 MB/s eta 0:00:00
# Installing collected packages: keras-nightly
# Successfully installed keras-nightly-3.7.0.dev2024110706

# %% [markdown]
# ## 3.미션1

# %% [markdown]
# 여러분은 노트북에서 얼굴 인식 파일을 실행시키기 위해 사전 학습 모델을 만들어야 합니다.
#
# 그 전에 가지고 있는 데이터셋을 **학습에 적합한 형태**로 만들어야 합니다.
#
# - 1) 데이터셋을 불러옵니다.
#     - 데이터셋은 2가지입니다. 본인의 얼굴 이미지 파일, 다른 사람의 얼굴 이미지 파일.
# - 2) 데이터셋을 전처리합니다.
#     - Keras에는 **실제로 존재하는 이미지 데이터를 처리**해주는 함수가 있습니다.

# %% [markdown]
# ### (1) 데이터셋 불러오기

# %% [markdown]
# * **세부 요구사항**
#     - 데이터셋을 불러옵니다.
#         - 데이터셋은 두 개의 압축 파일이어야 합니다.
#             1. lfw-deepfunneled.zip : Labeled Faces in the Wild 데이터셋
#             2. 여러분의 얼굴 이미지 데이터셋
#                 - 여러분의 얼굴 이미지가 담긴 **압축 파일**을 **Google Drive에 업로드** 하기를 권장합니다.
#                     - 이미지 파일 하나하나 업로드 하면 시간이 오래 걸립니다.
#     - 데이터셋 압축 파일을 **Colab에 폴더를 생성한 후 해제**하세요.
#         - 데이터셋 폴더를 **본인 얼굴 폴더, LFW 폴더로 나누어** 생성하는 것을 권장합니다.
#         - 만일 두 압축 파일을 하나의 폴더에 모두 해제하면 전처리가 더 까다로워질 것입니다.
#     - 예시 코드에서 사용한 라이브러리
#         - os, zipfile

# %% [markdown]
# #### 1) 본인 얼굴 이미지 데이터셋 불러오기

# %%
import os
import zipfile

# %%
data_myFace = os.path.join(path, 'Datasets/Keras/my_image.zip')
data_myFace
# Out:
# '/content/drive/MyDrive/project4/Datasets/Keras/my_image.zip'

# %%
## Colab에 생성할 본인 얼굴 폴더 경로
extract_folder = '/content/my_face'

## 위의 경로에 폴더가 없을 때 생성
if not os.path.exists(extract_folder) :
    os.makedirs(extract_folder)

## 위의 경로에 압축을 해제
with zipfile.ZipFile(data_myFace, 'r') as zip_ref :
    file_list = zip_ref.namelist()

    for f in file_list :
        if not f.endswith('/') and f.lower().endswith('.jpg') :
            file_name = os.path.basename(f)

            if not file_name.startswith('._') :
                d_path = os.path.join(extract_folder, file_name)

                with zip_ref.open(f) as source, open(d_path, 'wb') as target :
                    target.write(source.read())

# %%
## 생성된 본인 얼굴 이미지 데이터 폴더 안의 이미지 수
len(os.listdir(extract_folder) )
# Out:
# 7000

# %% [markdown]
# #### 2) 다른 얼굴 이미지 데이터셋 불러오기

# %%
data_other = os.path.join(path, 'Datasets/Keras/lfw-deepfunneled.zip')
data_myFace
# Out:
# '/content/drive/MyDrive/project4/Datasets/Keras/my_image.zip'

# %%
extract_folder = '/content/other_face'

if not os.path.exists(extract_folder):
    os.makedirs(extract_folder)

with zipfile.ZipFile(data_other, 'r') as zip_ref:
    file_list = zip_ref.namelist()

    for f in file_list:
        if not f.endswith('/') and f.lower().endswith('.jpg'):
            file_name = os.path.basename(f)
            if not file_name.startswith('._'):
                d_path = os.path.join(extract_folder, file_name)
                with zip_ref.open(f) as source, open(d_path, 'wb') as target:
                    target.write(source.read())

# %%
## Colab에 생성할 다른 얼굴 폴더 경로
extract_folder = '/content/other_face'

## 위의 경로에 폴더가 없을 때 생성
if not os.path.exists(extract_folder) :
    os.makedirs(extract_folder)

## 위의 경로에 압축을 해제
with zipfile.ZipFile(data_other, 'r') as zip_ref :
    file_list = zip_ref.namelist()

    for f in file_list :
        if not f.endswith('/') and f.lower().endswith('.jpg') :
            file_name = os.path.basename(f)

            if not file_name.startswith('._') :
                d_path = os.path.join(extract_folder, file_name)

                with zip_ref.open(f) as source, open(d_path, 'wb') as target :
                    target.write(source.read())

# %%
## 생성된 다른 사람 얼굴 이미지 데이터 폴더 안의 이미지 수
len(os.listdir(extract_folder) )
# Out:
# 13233

# %% [markdown]
# ### (2) 데이터셋 전처리
# * **세부 요구사항**
#     - 데이터셋을 전처리 합니다.
#         - Training set, Validation set, Test set으로 데이터셋을 나누어 주세요.
#             - 학습 과정에서 Training set, Validation set을 사용해야 합니다.
#             - 추론 과정에서 Test set을 사용해야 합니다.
#         - Keras의 **특정 함수**가 실제 존재하는 이미지 파일에 대한 전처리를 쉽게 도와줍니다.
#         - **특정 함수**에서 요구하는 폴더 구조가 있습니다. **특정 함수**를 사용한다면 이에 맞춰서 폴더를 생성해야 합니다.
#         - 각 데이터셋에 스케일링도 적용하세요.
#     - 예시 코드에서 사용한 라이브러리
#         - glob, random, shutil, numpy, keras

# %% [markdown]
# #### 1) 데이터셋 분할

# %%
import glob
import random
import shutil
import numpy as np

from keras.utils import load_img, img_to_array
from keras.utils import image_dataset_from_directory

# %%
## image_dataset_from_directory를 사용하기 위해 Colab에 폴더 생성

## 생성될 폴더의 경로
tr_data = '/content/tr_data'
te_data = '/content/te_data'

## 폴더가 존재하지 않을 때 폴더를 생성
if not os.path.exists(tr_data) :
    os.makedirs(tr_data)

if not os.path.exists(te_data) :
    os.makedirs(te_data)

## 폴더 생성 확인
print(os.path.exists(tr_data) )
print(os.path.exists(te_data) )
# Out:
# True
# True

# %%
## Keras의 image_dataset_from_directory를 사용하기 위해 Colab에 하위 폴더 생성

## 생성될 폴더에 대한 하위 폴더 생성
class_names = ['my', 'other']

for cn in class_names :
    temp = os.path.join(tr_data, cn)

    if not os.path.exists( temp ) :
        os.makedirs(temp)

    ## 폴더 생성 확인
    print(os.path.exists(temp))

for cn in class_names :
    temp = os.path.join(te_data, cn)

    if not os.path.exists( temp ) :
        os.makedirs(temp)

    ## 폴더 생성 확인
    print(os.path.exists(temp))
# Out:
# True
# True
# True
# True

# %%
## 본인 얼굴 데이터가 있는 폴더 경로의 파일 전체를 정렬하여 리스트화
img_list_my = sorted(glob.glob('/content/my_face/*',))

## 다른 얼굴 데이터가 있는 폴더 경로의 파일 전체를 정렬하여 리스트화
img_list_other = sorted(glob.glob('/content/other_face/*'))

## 이미지 갯수 확인
len(img_list_my), len(img_list_other)
# Out:
# (7000, 13233)

# %%
## 얼굴 데이터를 Training set, Test set으로 분할하기 위한 사전 작업
## 분할 재현성을 위한 난수 고정
random.seed(2024)
random.shuffle(img_list_my)
random.shuffle(img_list_other)

img_list_my[:5], img_list_other[:5]
# Out:
# (['/content/my_face/my_face_4542.jpg',
#   '/content/my_face/my_face_8245.jpg',
#   '/content/my_face/my_face_2189.jpg',
#   '/content/my_face/my_face_4033.jpg',
#   '/content/my_face/my_face_6878.jpg'],
#  ['/content/other_face/Jean-Claude_Van_Damme_0001.jpg',
#   '/content/other_face/Anna_Kournikova_0003.jpg',
#   '/content/other_face/Andy_Hebb_0002.jpg',
#   '/content/other_face/Nancy_Reagan_0002.jpg',
#   '/content/other_face/Lew_Rywin_0001.jpg'])

# %%
## Test set의 비율 설정
test_size = 0.2

## 나의 얼굴 파일 리스트와 다른 얼굴 파일 리스트에 대한 반복문
for i_l in [img_list_my, img_list_other] :
    ## 리스트의 길이 체크
    list_len = len(i_l)
    # list_len = 11000  ## 예시 파일의 이미지 갯수가 맞지 않아서 11000개까지만 사용
    ## 데이터 분할을 위한 인덱스 설정
    split_idx = int(list_len * (1 - test_size) )

    ## 인덱스를 이용해 상위 리스트를 Training set, Test set 2가지로 세분화
    list_tr = i_l[ : split_idx]
    list_te = i_l[split_idx : list_len]

    ## 현재 리스트가 나의 얼굴 파일 리스트와 같다면
    if i_l == img_list_my :
        ## "나의 얼굴 파일 리스트"의 파일을 Training set 폴더 안의 "나의 얼굴 폴더"로 복사
        ## 이동이 잘못 되었을 경우를 생각하여 복사로 진행
        for file_path in list_tr :
            f_name = file_path.split('/')
            shutil.copy(src=file_path,
                        dst=tr_data+'/my/'+f_name[-1]
                        )
            print(f'파일 이동 완료 : {f_name[-1]}')

        ## "나의 얼굴 파일 리스트"의 파일을 Test set 폴더 안의 "나의 얼굴 폴더"로 복사
        ## 이동이 잘못 되었을 경우를 생각하여 복사로 진행
        for file_path in list_te :
            f_name = file_path.split('/')
            shutil.copy(src=file_path,
                        dst=te_data+'/my/'+f_name[-1]
                        )
            print(f'파일 이동 완료 : {f_name[-1]}')

    ## 현재 리스트가 "나의 얼굴 파일 리스트"가 아니라면 (즉, "다른 사람 얼굴 파일 리스트"라면)
    else :
        ## "다른 사람 얼굴 파일 리스트"의 파일을 Training set 폴더 안의 "다른 사람 얼굴 폴더"로 복사
        ## 이동이 잘못 되었을 경우를 생각하여 복사로 진행
        for file_path in list_tr :
            f_name = file_path.split('/')
            shutil.copy(src=file_path,
                        dst=tr_data+'/other/'+f_name[-1],
                        )
            print(f'파일 이동 완료 : {f_name[-1]}')

        ## "다른 사람 얼굴 파일 리스트"의 파일을 Test set 폴더 안의 "다른 사람 얼굴 폴더"로 복사
        ## 이동이 잘못 되었을 경우를 생각하여 복사로 진행
        for file_path in list_te :
            f_name = file_path.split('/')
            shutil.copy(src=file_path,
                        dst=te_data+'/other/'+f_name[-1]
                        )
            print(f'파일 이동 완료 : {f_name[-1]}')
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 파일 이동 완료 : Judi_Dench_0002.jpg
# 파일 이동 완료 : Paul_Schrader_0001.jpg
# 파일 이동 완료 : Amy_Pascal_0001.jpg
# 파일 이동 완료 : Rose_Linkins_0001.jpg
# 파일 이동 완료 : Colin_Powell_0190.jpg
# 파일 이동 완료 : Mike_Farrar_0001.jpg
# 파일 이동 완료 : Paul_Henderson_0001.jpg
# 파일 이동 완료 : Kathleen_Glynn_0001.jpg
# 파일 이동 완료 : Pete_Sampras_0011.jpg
# 파일 이동 완료 : Pervez_Musharraf_0004.jpg
# 파일 이동 완료 : Tom_Rouen_0001.jpg
# 파일 이동 완료 : John_Bolton_0002.jpg
# 파일 이동 완료 : Kajsa_Bergqvist_0001.jpg
# 파일 이동 완료 : Gunter_Pleuger_0002.jpg
# 파일 이동 완료 : Placido_Domingo_0003.jpg
# 파일 이동 완료 : Tony_Blair_0054.jpg
# 파일 이동 완료 : George_W_Bush_0195.jpg
# 파일 이동 완료 : Oxana_Fedorova_0002.jpg
# 파일 이동 완료 : Gloria_Macapagal_Arroyo_0015.jpg
# 파일 이동 완료 : Jack_Straw_0027.jpg
# 파일 이동 완료 : Brian_Olson_0001.jpg
# 파일 이동 완료 : Ravan_AG_Farhadi_0001.jpg
# 파일 이동 완료 : Nobuyuki_Idei_0001.jpg
# 파일 이동 완료 : Rogelio_Montemayor_0001.jpg
# 파일 이동 완료 : Al_Pacino_0002.jpg
# 파일 이동 완료 : Hoda_Asfor_0001.jpg
# 파일 이동 완료 : Hitomi_Soga_0003.jpg
# 파일 이동 완료 : Norm_Coleman_0007.jpg
# 파일 이동 완료 : Dieter_Holzer_0001.jpg
# 파일 이동 완료 : Joschka_Fischer_0014.jpg
# 파일 이동 완료 : Beth_Jones_0001.jpg
# 파일 이동 완료 : Silvio_Berlusconi_0021.jpg
# 파일 이동 완료 : David_Surrett_0001.jpg
# 파일 이동 완료 : Boris_Trajkovski_0001.jpg
# 파일 이동 완료 : Jerry_Falwell_0001.jpg
# 파일 이동 완료 : James_Caan_0001.jpg
# 파일 이동 완료 : Ridley_Scott_0001.jpg
# 파일 이동 완료 : Ariel_Sharon_0056.jpg
# 파일 이동 완료 : Howard_Dean_0010.jpg
# 파일 이동 완료 : Robbie_Williams_0003.jpg
# 파일 이동 완료 : George_W_Bush_0057.jpg
# 파일 이동 완료 : Clay_Aiken_0002.jpg
# 파일 이동 완료 : David_Nalbandian_0010.jpg
# 파일 이동 완료 : George_W_Bush_0030.jpg
# 파일 이동 완료 : Kim_Yun-kyu_0001.jpg
# 파일 이동 완료 : Audrey_Sauret_0001.jpg
# 파일 이동 완료 : Colin_Powell_0038.jpg
# 파일 이동 완료 : Akbar_Hashemi_Rafsanjani_0001.jpg
# 파일 이동 완료 : David_Beckham_0002.jpg
# 파일 이동 완료 : Jamie_Cooke_0001.jpg
# 파일 이동 완료 : Warren_Buffett_0001.jpg
# 파일 이동 완료 : John_Sweeney_0001.jpg
# 파일 이동 완료 : Christine_Todd_Whitman_0004.jpg
# 파일 이동 완료 : Mario_Dominguez_0001.jpg
# 파일 이동 완료 : Pele_0001.jpg
# 파일 이동 완료 : Tom_Welch_0001.jpg
# 파일 이동 완료 : Selma_Phoenix_0001.jpg
# 파일 이동 완료 : Ali_Abbas_0002.jpg
# 파일 이동 완료 : Tom_Jones_0001.jpg
# 파일 이동 완료 : Serena_Williams_0035.jpg
# 파일 이동 완료 : Evo_Morales_0001.jpg
# 파일 이동 완료 : Dennis_Kucinich_0006.jpg
# 파일 이동 완료 : Polona_Bas_0001.jpg
# 파일 이동 완료 : Abdullah_Gul_0018.jpg
# 파일 이동 완료 : John_Geoghan_0001.jpg
# 파일 이동 완료 : Yoon_Jeong_Cho_0001.jpg
# 파일 이동 완료 : Michael_Caine_0004.jpg
# 파일 이동 완료 : Jim_Piper_0001.jpg
# 파일 이동 완료 : John_Negroponte_0022.jpg
# 파일 이동 완료 : Sanjay_Gupta_0001.jpg
# 파일 이동 완료 : Earl_Fritts_0001.jpg
# 파일 이동 완료 : Pedro_Almodovar_0004.jpg
# 파일 이동 완료 : Donald_Rumsfeld_0032.jpg
# 파일 이동 완료 : Pamela_Anderson_0002.jpg
# 파일 이동 완료 : Ronnie_Jagday_0001.jpg
# 파일 이동 완료 : Joschka_Fischer_0015.jpg
# 파일 이동 완료 : Martin_Cauchon_0001.jpg
# 파일 이동 완료 : Hosni_Mubarak_0006.jpg
# 파일 이동 완료 : Michael_Broad_0001.jpg
# 파일 이동 완료 : Cate_Blanchett_0001.jpg
# 파일 이동 완료 : Gabriel_Batistuta_0001.jpg
# 파일 이동 완료 : Jen_Bice_0001.jpg
# 파일 이동 완료 : Claudio_Ranieri_0001.jpg
# 파일 이동 완료 : Colin_Powell_0100.jpg
# 파일 이동 완료 : Jack_Knowlton_0001.jpg
# 파일 이동 완료 : Michael_Phelps_0001.jpg
# 파일 이동 완료 : Brian_Campbell_0001.jpg
# 파일 이동 완료 : Vince_Carter_0004.jpg
# 파일 이동 완료 : Renee_Zellweger_0013.jpg
# 파일 이동 완료 : George_W_Bush_0270.jpg
# 파일 이동 완료 : Sean_OKeefe_0005.jpg
# 파일 이동 완료 : Hans_Blix_0038.jpg
# 파일 이동 완료 : Wayne_Ferreira_0004.jpg
# 파일 이동 완료 : Luiz_Inacio_Lula_da_Silva_0045.jpg
# 파일 이동 완료 : Julie_Gerberding_0009.jpg
# 파일 이동 완료 : John_Negroponte_0029.jpg
# 파일 이동 완료 : Tavis_Smiley_0001.jpg
# 파일 이동 완료 : Gerard_Tronche_0001.jpg
# 파일 이동 완료 : Deece_Eckstein_0001.jpg
# 파일 이동 완료 : Teresa_Heinz_Kerry_0001.jpg
# 파일 이동 완료 : Yoo_Jay-Kun_0001.jpg
# 파일 이동 완료 : Tom_Daschle_0018.jpg
# 파일 이동 완료 : Vaclav_Klaus_0001.jpg
# 파일 이동 완료 : Allen_Iverson_0002.jpg
# 파일 이동 완료 : Madeleine_Albright_0003.jpg
# 파일 이동 완료 : Chris_Cooper_0001.jpg
# 파일 이동 완료 : Nestor_Kirchner_0031.jpg
# 파일 이동 완료 : Zhang_Wenkang_0001.jpg
# 파일 이동 완료 : Claire_Hentzen_0002.jpg
# 파일 이동 완료 : Prince_Claus_0002.jpg
# 파일 이동 완료 : John_Allen_Muhammad_0007.jpg
# 파일 이동 완료 : Hideki_Sato_0001.jpg
# 파일 이동 완료 : Tony_Bennett_0002.jpg
# 파일 이동 완료 : Condoleezza_Rice_0010.jpg
# 파일 이동 완료 : Tom_Crean_0002.jpg
# 파일 이동 완료 : Jiri_Novak_0008.jpg
# 파일 이동 완료 : George_W_Bush_0392.jpg
# 파일 이동 완료 : Annette_Lu_0003.jpg
# 파일 이동 완료 : Basdeo_Panday_0001.jpg
# 파일 이동 완료 : Gray_Davis_0021.jpg
# 파일 이동 완료 : Hugh_Grant_0003.jpg
# 파일 이동 완료 : Gerhard_Schroeder_0032.jpg
# 파일 이동 완료 : Ernie_Eves_0002.jpg
# 파일 이동 완료 : Jack_Straw_0013.jpg
# 파일 이동 완료 : Sheryl_Crow_0007.jpg
# 파일 이동 완료 : Oscar_DLeon_0001.jpg
# 파일 이동 완료 : Silvio_Berlusconi_0004.jpg
# 파일 이동 완료 : Dick_Smothers_0001.jpg
# 파일 이동 완료 : Andy_Lau_0001.jpg
# 파일 이동 완료 : Dot_Helms_0001.jpg
# 파일 이동 완료 : Venus_Williams_0014.jpg
# 파일 이동 완료 : Juergen_Braehmer_0001.jpg
# 파일 이동 완료 : Ivan_Stambolic_0001.jpg
# 파일 이동 완료 : Tom_Daschle_0010.jpg
# 파일 이동 완료 : Colin_Powell_0160.jpg
# 파일 이동 완료 : Hiroyuki_Yoshino_0001.jpg
# 파일 이동 완료 : Yannos_Papantoniou_0001.jpg
# 파일 이동 완료 : Antwun_Echols_0001.jpg
# 파일 이동 완료 : Roger_Mahony_0001.jpg
# 파일 이동 완료 : Mohammed_Al-Douri_0001.jpg
# 파일 이동 완료 : Barry_Hinson_0001.jpg
# 파일 이동 완료 : Ivan_Lee_0001.jpg
# 파일 이동 완료 : Saddam_Hussein_0002.jpg
# 파일 이동 완료 : Gina_Gershon_0001.jpg
# 파일 이동 완료 : Colin_Powell_0194.jpg
# 파일 이동 완료 : Hana_Sadiq_0001.jpg
# 파일 이동 완료 : Manuel_Jesus_0001.jpg
# 파일 이동 완료 : Steve_Ballmer_0002.jpg
# 파일 이동 완료 : John_Travolta_0007.jpg
# 파일 이동 완료 : Normand_Legault_0001.jpg
# 파일 이동 완료 : Norodom_Chakrapong_0001.jpg
# 파일 이동 완료 : Pervez_Musharraf_0018.jpg
# 파일 이동 완료 : Jean-Rene_Fourtou_0001.jpg
# 파일 이동 완료 : William_Macy_0002.jpg
# 파일 이동 완료 : Gary_Winnick_0002.jpg
# 파일 이동 완료 : George_Robertson_0017.jpg
# 파일 이동 완료 : Jesse_Harris_0001.jpg
# 파일 이동 완료 : Nicanor_Duarte_Frutos_0010.jpg
# 파일 이동 완료 : Benazir_Bhutto_0003.jpg
# 파일 이동 완료 : William_Donaldson_0002.jpg
# 파일 이동 완료 : Tony_Blair_0017.jpg
# 파일 이동 완료 : Ken_Loach_0001.jpg
# 파일 이동 완료 : Shigeo_Nagashima_0001.jpg
# 파일 이동 완료 : Paul_Burrell_0002.jpg
# 파일 이동 완료 : Hasan_Wirayuda_0001.jpg
# 파일 이동 완료 : George_W_Bush_0405.jpg
# 파일 이동 완료 : Tom_Crean_0004.jpg
# 파일 이동 완료 : Jessica_Simpson_0001.jpg
# 파일 이동 완료 : David_Wells_0006.jpg
# 파일 이동 완료 : Zhang_Ziyi_0001.jpg
# 파일 이동 완료 : Koji_Uehara_0001.jpg
# 파일 이동 완료 : Emmanuelle_Beart_0003.jpg
# 파일 이동 완료 : Yasar_Yakis_0003.jpg
# 파일 이동 완료 : Britney_Spears_0003.jpg
# 파일 이동 완료 : Mohammed_Al-Douri_0011.jpg
# 파일 이동 완료 : Kevin_Costner_0008.jpg
# 파일 이동 완료 : Kiki_Vandeweghe_0002.jpg
# 파일 이동 완료 : Costas_Simitis_0002.jpg
# 파일 이동 완료 : Bob_Bowlsby_0001.jpg
# 파일 이동 완료 : Vanessa_Incontrada_0004.jpg
# 파일 이동 완료 : Hugo_Chavez_0036.jpg
# 파일 이동 완료 : Helio_Castroneves_0001.jpg
# 파일 이동 완료 : Dave_Barr_0001.jpg
# 파일 이동 완료 : Bridget_Fonda_0001.jpg
# 파일 이동 완료 : Ricardo_Monasterio_0002.jpg
# 파일 이동 완료 : Ashanti_0001.jpg
# 파일 이동 완료 : Sachin_Tendulkar_0001.jpg
# 파일 이동 완료 : Recep_Tayyip_Erdogan_0012.jpg
# 파일 이동 완료 : Alimzhan_Tokhtakhounov_0002.jpg
# 파일 이동 완료 : Oleksandr_Moroz_0001.jpg
# 파일 이동 완료 : Beth_Jones_0002.jpg
# 파일 이동 완료 : Gisele_Bundchen_0001.jpg
# 파일 이동 완료 : Francis_Mer_0002.jpg
# 파일 이동 완료 : Chris_Noth_0001.jpg
# 파일 이동 완료 : Mark_Butcher_0001.jpg
# 파일 이동 완료 : Fernando_Henrique_Cardoso_0005.jpg
# 파일 이동 완료 : Lucio_Stanca_0001.jpg
# 파일 이동 완료 : David_Nalbandian_0001.jpg
# 파일 이동 완료 : Larry_Ellison_0003.jpg
# 파일 이동 완료 : Rogerio_Romero_0001.jpg
# 파일 이동 완료 : Tony_Blair_0025.jpg
# 파일 이동 완료 : Donald_Rumsfeld_0021.jpg
# 파일 이동 완료 : Faye_Alibocus_0001.jpg
# 파일 이동 완료 : Munir_Akram_0001.jpg
# 파일 이동 완료 : Recep_Tayyip_Erdogan_0001.jpg
# 파일 이동 완료 : Mark_Komara_0001.jpg
# 파일 이동 완료 : Tab_Turner_0001.jpg
# 파일 이동 완료 : Brian_Jordan_0001.jpg
# 파일 이동 완료 : Miguel_Hakim_0001.jpg
# 파일 이동 완료 : George_W_Bush_0123.jpg
# 파일 이동 완료 : Roy_Williams_0004.jpg
# 파일 이동 완료 : Robert_Kocharian_0004.jpg
# 파일 이동 완료 : Donald_Rumsfeld_0007.jpg
# 파일 이동 완료 : John_Wayne_0001.jpg
# 파일 이동 완료 : Bill_Clinton_0022.jpg
# 파일 이동 완료 : John_Banko_0001.jpg
# 파일 이동 완료 : Jeffrey_Scott_Postell_0002.jpg
# 파일 이동 완료 : Chris_Tucker_0001.jpg
# 파일 이동 완료 : Mara_Georges_0001.jpg
# 파일 이동 완료 : Jiri_Novak_0010.jpg
# 파일 이동 완료 : Sherry_Irving_0001.jpg
# 파일 이동 완료 : Milo_Maestrecampo_0001.jpg
# 파일 이동 완료 : Larenz_Tate_0001.jpg
# 파일 이동 완료 : Khaled_Sawalhi_0001.jpg
# 파일 이동 완료 : Drew_Gooden_0001.jpg
# 파일 이동 완료 : Vladimir_Putin_0039.jpg
# 파일 이동 완료 : Rubens_Barrichello_0003.jpg
# 파일 이동 완료 : Jesse_Jackson_0008.jpg
# 파일 이동 완료 : Charles_Bronson_0003.jpg
# 파일 이동 완료 : George_W_Bush_0522.jpg
# 파일 이동 완료 : Gonzalo_Sanchez_de_Lozada_0005.jpg
# 파일 이동 완료 : Rudolph_Giuliani_0015.jpg
# 파일 이동 완료 : Janis_Ruth_Coulter_0001.jpg
# 파일 이동 완료 : Pervez_Musharraf_0007.jpg
# 파일 이동 완료 : Jennifer_Aniston_0017.jpg
# 파일 이동 완료 : Megan_Mullally_0002.jpg
# 파일 이동 완료 : Maritza_Macias_Furano_0001.jpg
# 파일 이동 완료 : Tom_Watson_0003.jpg
# 파일 이동 완료 : George_W_Bush_0258.jpg
# 파일 이동 완료 : Kobe_Bryant_0003.jpg
# 파일 이동 완료 : Thomas_Bjorn_0002.jpg
# 파일 이동 완료 : John_Ashcroft_0005.jpg
# 파일 이동 완료 : Charles_Moose_0005.jpg
# 파일 이동 완료 : Vladimir_Putin_0032.jpg
# 파일 이동 완료 : Colin_Powell_0006.jpg
# 파일 이동 완료 : Robert_Redford_0003.jpg
# 파일 이동 완료 : Norbert_van_Heyst_0001.jpg
# 파일 이동 완료 : Ali_Fallahian_0001.jpg
# 파일 이동 완료 : Ishaq_Shahryar_0002.jpg
# 파일 이동 완료 : Ion_Iliescu_0001.jpg
# 파일 이동 완료 : Luiz_Inacio_Lula_da_Silva_0044.jpg
# 파일 이동 완료 : Cruz_Bustamante_0005.jpg
# 파일 이동 완료 : Junichiro_Koizumi_0040.jpg
# 파일 이동 완료 : Ethan_Hawke_0001.jpg
# 파일 이동 완료 : John_McEnroe_0001.jpg
# 파일 이동 완료 : Hal_Sutton_0001.jpg
# 파일 이동 완료 : John_Howard_0006.jpg
# 파일 이동 완료 : Juan_Carlos_Ferrero_0027.jpg
# 파일 이동 완료 : Gray_Davis_0012.jpg
# 파일 이동 완료 : Laura_Bush_0015.jpg
# 파일 이동 완료 : Eric_Rosser_0002.jpg
# 파일 이동 완료 : Eduardo_Duhalde_0006.jpg
# 파일 이동 완료 : Alvaro_Uribe_0005.jpg
# 파일 이동 완료 : LeAnn_Rimes_0001.jpg
# 파일 이동 완료 : Joseph_Biden_0001.jpg
# 파일 이동 완료 : Julianne_Moore_0002.jpg
# 파일 이동 완료 : Paul_Michael_Daniels_0001.jpg
# 파일 이동 완료 : Stephen_Frears_0001.jpg
# 파일 이동 완료 : Naomi_Watts_0022.jpg
# 파일 이동 완료 : Pham_Sy_Chien_0001.jpg
# 파일 이동 완료 : Hal_Gehman_0001.jpg
# 파일 이동 완료 : Iain_Duncan_Smith_0003.jpg
# 파일 이동 완료 : Pedro_Solbes_0004.jpg
# 파일 이동 완료 : AJ_Lamas_0001.jpg
# 파일 이동 완료 : Norah_Jones_0006.jpg
# 파일 이동 완료 : Chip_Burrus_0001.jpg
# 파일 이동 완료 : Debbie_Reynolds_0004.jpg
# 파일 이동 완료 : Cha_Yung-gu_0001.jpg
# 파일 이동 완료 : Chuck_Hagel_0001.jpg
# 파일 이동 완료 : Paul_Pierce_0001.jpg
# 파일 이동 완료 : Eugene_Teslovic_0001.jpg
# 파일 이동 완료 : Julianne_Moore_0014.jpg
# 파일 이동 완료 : Jay_Garner_0002.jpg
# 파일 이동 완료 : Billy_Andrade_0001.jpg
# 파일 이동 완료 : Clare_Short_0001.jpg
# 파일 이동 완료 : George_W_Bush_0416.jpg
# 파일 이동 완료 : Stefan_Holm_0001.jpg
# 파일 이동 완료 : Alastair_Johnston_0001.jpg
# 파일 이동 완료 : Ben_Cohen_0001.jpg
# 파일 이동 완료 : Viara_Vike-Freiberga_0001.jpg
# 파일 이동 완료 : Imran_Khan_0001.jpg
# 파일 이동 완료 : Xanana_Gusmao_0002.jpg
# 파일 이동 완료 : Greg_Gilbert_0002.jpg
# 파일 이동 완료 : John_Ashcroft_0049.jpg
# 파일 이동 완료 : Abdullah_Gul_0014.jpg
# 파일 이동 완료 : John_Travolta_0004.jpg
# 파일 이동 완료 : Phillips_Idowu_0001.jpg
# 파일 이동 완료 : Tom_Glavine_0002.jpg
# 파일 이동 완료 : Jim_Thome_0001.jpg
# 파일 이동 완료 : Tim_Allen_0001.jpg
# 파일 이동 완료 : Hu_Jintao_0006.jpg
# 파일 이동 완료 : Marcus_Garrettson_0001.jpg
# 파일 이동 완료 : Andrew_Fastow_0001.jpg
# 파일 이동 완료 : Don_Nickles_0001.jpg
# 파일 이동 완료 : Donatella_Versace_0003.jpg
# 파일 이동 완료 : Tony_Blair_0075.jpg
# 파일 이동 완료 : George_W_Bush_0267.jpg
# 파일 이동 완료 : Bob_Alper_0001.jpg
# 파일 이동 완료 : George_W_Bush_0038.jpg
# 파일 이동 완료 : Dennis_Kozlowski_0002.jpg
# 파일 이동 완료 : Winona_Ryder_0014.jpg
# 파일 이동 완료 : Cheryl_Little_0001.jpg
# 파일 이동 완료 : Sarah_Jessica_Parker_0002.jpg
# 파일 이동 완료 : George_W_Bush_0164.jpg
# 파일 이동 완료 : David_Anderson_0004.jpg
# 파일 이동 완료 : Sergei_Yastrzhembsky_0001.jpg
# 파일 이동 완료 : Nathalie_Gagnon_0001.jpg
# 파일 이동 완료 : Elizabeth_Hurley_0005.jpg
# 파일 이동 완료 : Dave_McNally_0001.jpg
# 파일 이동 완료 : Jack_Straw_0009.jpg
# 파일 이동 완료 : Queen_Beatrix_0002.jpg
# 파일 이동 완료 : Colin_Powell_0176.jpg
# 파일 이동 완료 : Donald_Rumsfeld_0062.jpg
# 파일 이동 완료 : Elena_Bovina_0001.jpg
# 파일 이동 완료 : Roy_Jones_Jr_0002.jpg
# 파일 이동 완료 : Aicha_El_Ouafi_0002.jpg
# 파일 이동 완료 : Simona_Hradil_0001.jpg
# 파일 이동 완료 : Frank_Beamer_0001.jpg
# 파일 이동 완료 : Olene_Walker_0001.jpg
# 파일 이동 완료 : Kristin_Chenoweth_0001.jpg
# 파일 이동 완료 : John_Warner_0003.jpg
# 파일 이동 완료 : George_W_Bush_0374.jpg
# 파일 이동 완료 : Ai_Sugiyama_0003.jpg
# 파일 이동 완료 : Anders_Ebbeson_0003.jpg
# 파일 이동 완료 : Abba_Eban_0001.jpg
# 파일 이동 완료 : JK_Rowling_0003.jpg
# 파일 이동 완료 : James_Becker_0001.jpg
# 파일 이동 완료 : Qais_al-Kazali_0001.jpg
# 파일 이동 완료 : Sohail_Abbas_0001.jpg
# 파일 이동 완료 : Fred_Funk_0002.jpg
# 파일 이동 완료 : Michael_Haneke_0001.jpg
# 파일 이동 완료 : Adam_Sandler_0001.jpg
# 파일 이동 완료 : Sylvia_Plachy_0001.jpg
# 파일 이동 완료 : Russell_Simmons_0001.jpg
# 파일 이동 완료 : George_W_Bush_0236.jpg
# 파일 이동 완료 : John_Ashcroft_0044.jpg
# 파일 이동 완료 : Naji_Sabri_0003.jpg
# 파일 이동 완료 : Junichiro_Koizumi_0036.jpg
# 파일 이동 완료 : Nancy_Humbert_0001.jpg
# 파일 이동 완료 : Suzanne_Gaudet_0001.jpg
# 파일 이동 완료 : Tiger_Woods_0021.jpg
# 파일 이동 완료 : Catherine_Woodard_0001.jpg
# 파일 이동 완료 : Rina_Lazo_0001.jpg
# 파일 이동 완료 : George_W_Bush_0188.jpg
# 파일 이동 완료 : Gerhard_Schroeder_0079.jpg
# 파일 이동 완료 : Tim_Henman_0013.jpg
# 파일 이동 완료 : Queen_Elizabeth_II_0002.jpg
# 파일 이동 완료 : Jane_Russell_0001.jpg
# 파일 이동 완료 : Kim_Dae-jung_0005.jpg
# 파일 이동 완료 : Hugo_Chavez_0010.jpg
# 파일 이동 완료 : Jennifer_Lopez_0002.jpg
# 파일 이동 완료 : George_W_Bush_0262.jpg
# 파일 이동 완료 : George_W_Bush_0082.jpg
# 파일 이동 완료 : Jose_Maria_Aznar_0022.jpg
# 파일 이동 완료 : Sarah_Hughes_0002.jpg
# 파일 이동 완료 : Jewel_Howard-Taylor_0001.jpg
# 파일 이동 완료 : Jeffrey_Donaldson_0001.jpg
# 파일 이동 완료 : Tony_Blair_0067.jpg
# 파일 이동 완료 : Oscar_de_la_Renta_0001.jpg
# 파일 이동 완료 : Hu_Jintao_0011.jpg
# 파일 이동 완료 : Edward_Albee_0001.jpg
# 파일 이동 완료 : Sharon_Frey_0001.jpg
# 파일 이동 완료 : Enrique_Bolanos_0001.jpg
# 파일 이동 완료 : James_Kopp_0004.jpg
# 파일 이동 완료 : Luiz_Inacio_Lula_da_Silva_0022.jpg
# 파일 이동 완료 : George_HW_Bush_0012.jpg
# 파일 이동 완료 : George_W_Bush_0463.jpg
# 파일 이동 완료 : Mahmoud_Abbas_0027.jpg
# 파일 이동 완료 : Jake_Gyllenhaal_0005.jpg
# 파일 이동 완료 : Annie_Machon_0001.jpg
# 파일 이동 완료 : Ariel_Sharon_0027.jpg
# 파일 이동 완료 : Colin_Powell_0096.jpg
# 파일 이동 완료 : Rick_Caruso_0001.jpg
# 파일 이동 완료 : Grace_Brinell_0001.jpg
# 파일 이동 완료 : George_W_Bush_0388.jpg
# 파일 이동 완료 : John_Sidgmore_0001.jpg
# 파일 이동 완료 : Lindsay_Davenport_0016.jpg
# 파일 이동 완료 : Vanessa_Incontrada_0003.jpg
# 파일 이동 완료 : Joseph_Blatter_0001.jpg
# 파일 이동 완료 : Colin_Powell_0154.jpg
# 파일 이동 완료 : Fran_Drescher_0001.jpg
# 파일 이동 완료 : Damon_van_Dam_0001.jpg
# 파일 이동 완료 : Kevin_Costner_0002.jpg
# 파일 이동 완료 : Arnold_Schwarzenegger_0024.jpg
# 파일 이동 완료 : George_W_Bush_0336.jpg
# 파일 이동 완료 : Anna_Kournikova_0001.jpg
# 파일 이동 완료 : Rudolph_Giuliani_0019.jpg
# 파일 이동 완료 : Wen_Jiabao_0001.jpg
# 파일 이동 완료 : George_W_Bush_0110.jpg
# 파일 이동 완료 : Julianne_Moore_0011.jpg
# 파일 이동 완료 : Pierce_Brosnan_0011.jpg
# 파일 이동 완료 : Peter_Ueberroth_0001.jpg
# 파일 이동 완료 : Colin_Powell_0054.jpg
# 파일 이동 완료 : Lleyton_Hewitt_0005.jpg
# 파일 이동 완료 : Scott_Sullivan_0002.jpg
# 파일 이동 완료 : Silvio_Berlusconi_0016.jpg
# 파일 이동 완료 : George_W_Bush_0434.jpg
# 파일 이동 완료 : Steven_Seagal_0001.jpg
# 파일 이동 완료 : Pierre_Pettigrew_0001.jpg
# 파일 이동 완료 : Melvin_Talbert_0001.jpg
# 파일 이동 완료 : Frank_Marshall_0001.jpg
# 파일 이동 완료 : Fernando_Henrique_Cardoso_0003.jpg
# 파일 이동 완료 : Robert_Bonner_0002.jpg
# 파일 이동 완료 : Edward_Flynn_0001.jpg
# 파일 이동 완료 : George_W_Bush_0470.jpg
# 파일 이동 완료 : Nestor_Kirchner_0020.jpg
# 파일 이동 완료 : Donald_Rumsfeld_0078.jpg
# 파일 이동 완료 : Christopher_Reeve_0003.jpg
# 파일 이동 완료 : Steven_Van_Zandt_0001.jpg
# 파일 이동 완료 : Tzipora_Obziler_0001.jpg
# 파일 이동 완료 : Mike_Krzyzewski_0005.jpg
# 파일 이동 완료 : Meryl_Streep_0005.jpg
# 파일 이동 완료 : Jim_Abbott_0001.jpg
# 파일 이동 완료 : Roger_Federer_0003.jpg
# 파일 이동 완료 : Alec_Baldwin_0002.jpg
# 파일 이동 완료 : John_Paul_II_0007.jpg
# 파일 이동 완료 : James_Morris_0001.jpg
# 파일 이동 완료 : Luis_Horna_0002.jpg
# 파일 이동 완료 : Jane_Pauley_0001.jpg
# 파일 이동 완료 : Dianne_Feinstein_0001.jpg
# 파일 이동 완료 : Bob_Beauprez_0001.jpg
# 파일 이동 완료 : Vicente_Fox_0025.jpg
# 파일 이동 완료 : Horst_Koehler_0002.jpg
# 파일 이동 완료 : Robert_Mugabe_0002.jpg
# 파일 이동 완료 : Priscilla_Owen_0002.jpg
# 파일 이동 완료 : Mark_Mariscal_0001.jpg
# 파일 이동 완료 : Woody_Allen_0005.jpg
# 파일 이동 완료 : Daniel_Zelman_0001.jpg
# 파일 이동 완료 : George_W_Bush_0514.jpg
# 파일 이동 완료 : Arnold_Schwarzenegger_0019.jpg
# 파일 이동 완료 : Paul_ONeill_0003.jpg
# 파일 이동 완료 : Severino_Antinori_0001.jpg
# 파일 이동 완료 : Idi_Amin_0001.jpg
# 파일 이동 완료 : Erin_Hershey_Presley_0001.jpg
# 파일 이동 완료 : Wayne_Brady_0001.jpg
# 파일 이동 완료 : Naomi_Watts_0016.jpg
# 파일 이동 완료 : Carlos_Moya_0004.jpg
# 파일 이동 완료 : Asa_Hutchinson_0002.jpg
# 파일 이동 완료 : Jimmy_Kimmel_0001.jpg
# 파일 이동 완료 : Paul_Burrell_0001.jpg
# 파일 이동 완료 : Oprah_Winfrey_0004.jpg
# 파일 이동 완료 : Joan_Claybrook_0002.jpg
# 파일 이동 완료 : George_W_Bush_0357.jpg
# 파일 이동 완료 : Mohamed_ElBaradei_0004.jpg
# 파일 이동 완료 : Hee-Won_Han_0002.jpg
# 파일 이동 완료 : Edmund_Stoiber_0004.jpg
# 파일 이동 완료 : Trudi_Lacey_0001.jpg
# 파일 이동 완료 : Serge_Klarsfeld_0001.jpg
# 파일 이동 완료 : Paul_Kagame_0002.jpg
# 파일 이동 완료 : Jean_Chretien_0029.jpg
# 파일 이동 완료 : Arminio_Fraga_0003.jpg
# 파일 이동 완료 : George_W_Bush_0498.jpg
# 파일 이동 완료 : Venus_Williams_0003.jpg
# 파일 이동 완료 : Hugo_Chavez_0051.jpg
# 파일 이동 완료 : Joe_Nichols_0001.jpg
# 파일 이동 완료 : Robert_Evans_0001.jpg
# 파일 이동 완료 : Roberto_Carlos_0004.jpg
# 파일 이동 완료 : Andy_Perez_0001.jpg
# 파일 이동 완료 : Colin_Powell_0223.jpg
# 파일 이동 완료 : Junichiro_Koizumi_0058.jpg
# 파일 이동 완료 : Robert_Lee_Yates_Jr_0001.jpg
# 파일 이동 완료 : Mario_Lemieux_0001.jpg
# 파일 이동 완료 : Kimi_Raikkonen_0002.jpg
# 파일 이동 완료 : Pierre_Boulanger_0002.jpg
# 파일 이동 완료 : Pete_Sampras_0018.jpg
# 파일 이동 완료 : Michael_Bloomberg_0001.jpg
# 파일 이동 완료 : Colin_Powell_0084.jpg
# 파일 이동 완료 : Patrick_Leahy_0002.jpg
# 파일 이동 완료 : Gordana_Grubin_0001.jpg
# 파일 이동 완료 : Giuseppe_Gibilisco_0002.jpg
# 파일 이동 완료 : Cindy_Taylor_0001.jpg
# 파일 이동 완료 : Spike_Lee_0001.jpg
# 파일 이동 완료 : George_Clooney_0009.jpg
# 파일 이동 완료 : Erin_Brockovich_0001.jpg
# 파일 이동 완료 : Celine_Dion_0003.jpg
# 파일 이동 완료 : Tina_Sinatra_0001.jpg
# 파일 이동 완료 : Vicente_Fernandez_0003.jpg
# 파일 이동 완료 : Taha_Yassin_Ramadan_0001.jpg
# 파일 이동 완료 : George_W_Bush_0479.jpg
# 파일 이동 완료 : Mahmoud_Al_Zhar_0001.jpg
# 파일 이동 완료 : Carlos_Savedra_0001.jpg
# 파일 이동 완료 : Felipe_Perez_Roque_0001.jpg
# 파일 이동 완료 : Jennifer_Lopez_0013.jpg
# 파일 이동 완료 : Lleyton_Hewitt_0011.jpg
# 파일 이동 완료 : George_W_Bush_0214.jpg
# 파일 이동 완료 : John_Abizaid_0007.jpg
# 파일 이동 완료 : Cindy_Klassen_0001.jpg
# 파일 이동 완료 : George_Ryan_0002.jpg
# 파일 이동 완료 : Gerhard_Schroeder_0056.jpg
# 파일 이동 완료 : Carlos_Menem_0016.jpg
# 파일 이동 완료 : Goran_Persson_0001.jpg
# 파일 이동 완료 : Jim_Carrey_0003.jpg
# 파일 이동 완료 : Tom_Hanks_0002.jpg
# 파일 이동 완료 : Olivier_Boulay_0001.jpg
# 파일 이동 완료 : Jonathan_Edwards_0001.jpg
# 파일 이동 완료 : Amanda_Bynes_0003.jpg
# 파일 이동 완료 : Steven_Spielberg_0003.jpg
# 파일 이동 완료 : Judy_Spreckels_0001.jpg
# 파일 이동 완료 : Luis_Gonzalez_Macchi_0005.jpg
# 파일 이동 완료 : Michael_Linscott_0001.jpg
# 파일 이동 완료 : Robert_Zoellick_0004.jpg
# 파일 이동 완료 : Prince_Harry_0003.jpg
# 파일 이동 완료 : Nia_Vardalos_0005.jpg
# 파일 이동 완료 : Evan_Rachel_Wood_0002.jpg
# 파일 이동 완료 : Roger_Penske_0001.jpg
# 파일 이동 완료 : Angelina_Jolie_0010.jpg
# 파일 이동 완료 : Lucy_Liu_0002.jpg
# 파일 이동 완료 : Paris_Hilton_0001.jpg
# 파일 이동 완료 : Adrian_Fernandez_0001.jpg
# 파일 이동 완료 : Lindsay_Davenport_0008.jpg
# 파일 이동 완료 : Odai_Hussein_0001.jpg
# 파일 이동 완료 : Tony_Blair_0084.jpg
# 파일 이동 완료 : Tony_Blair_0055.jpg
# 파일 이동 완료 : Caio_Blat_0001.jpg
# 파일 이동 완료 : Amelie_Mauresmo_0003.jpg
# 파일 이동 완료 : Paul_Burrell_0009.jpg
# 파일 이동 완료 : William_Donaldson_0006.jpg
# 파일 이동 완료 : Javier_Camara_0001.jpg
# 파일 이동 완료 : Donald_Rumsfeld_0048.jpg
# 파일 이동 완료 : Nate_Hybl_0001.jpg
# 파일 이동 완료 : Henrique_Meirelles_0001.jpg
# 파일 이동 완료 : Jude_Law_0001.jpg
# 파일 이동 완료 : BB_King_0001.jpg
# 파일 이동 완료 : Frank_Lautenberg_0001.jpg
# 파일 이동 완료 : James_McPherson_0001.jpg
# 파일 이동 완료 : Tom_Daschle_0016.jpg
# 파일 이동 완료 : Condoleezza_Rice_0007.jpg
# 파일 이동 완료 : Claire_Tomalin_0001.jpg
# 파일 이동 완료 : Marcella_Anderson_0001.jpg
# 파일 이동 완료 : Ian_Thorpe_0007.jpg
# 파일 이동 완료 : Jean_Charest_0014.jpg
# 파일 이동 완료 : Gerry_Adams_0004.jpg
# 파일 이동 완료 : Elmar_Brok_0001.jpg
# 파일 이동 완료 : Tommy_Franks_0001.jpg
# 파일 이동 완료 : Takuma_Sato_0001.jpg
# 파일 이동 완료 : Tyron_Garner_0002.jpg
# 파일 이동 완료 : Carlos_Menem_0013.jpg
# 파일 이동 완료 : Angelina_Jolie_0012.jpg
# 파일 이동 완료 : Roger_Cook_0001.jpg
# 파일 이동 완료 : John_Negroponte_0018.jpg
# 파일 이동 완료 : Gerhard_Schroeder_0050.jpg
# 파일 이동 완료 : Jeremy_Gompertz_0001.jpg
# 파일 이동 완료 : GL_Peiris_0001.jpg
# 파일 이동 완료 : Martie_Maguire_0001.jpg
# 파일 이동 완료 : Mark_Warner_0001.jpg
# 파일 이동 완료 : Ahmed_Chalabi_0001.jpg
# 파일 이동 완료 : Salma_Hayek_0011.jpg
# 파일 이동 완료 : Robert_Evans_0002.jpg
# 파일 이동 완료 : Joe_Torre_0001.jpg
# 파일 이동 완료 : George_W_Bush_0037.jpg
# 파일 이동 완료 : Roman_Polanski_0006.jpg
# 파일 이동 완료 : Colin_Montgomerie_0002.jpg
# 파일 이동 완료 : Bode_Miller_0001.jpg
# 파일 이동 완료 : Colin_Powell_0021.jpg
# 파일 이동 완료 : Rita_Grande_0003.jpg
# 파일 이동 완료 : Arminio_Fraga_0002.jpg
# 파일 이동 완료 : Gerry_Parsky_0002.jpg
# 파일 이동 완료 : John_Gruden_0001.jpg
# 파일 이동 완료 : Yasar_Yakis_0001.jpg
# 파일 이동 완료 : Colin_Powell_0114.jpg
# 파일 이동 완료 : John_Walsh_0001.jpg
# 파일 이동 완료 : Richard_Greenberg_0001.jpg
# 파일 이동 완료 : Choi_Yun-yong_0001.jpg
# 파일 이동 완료 : Jean-David_Levitte_0006.jpg
# 파일 이동 완료 : William_Bratton_0001.jpg
# 파일 이동 완료 : Alejandro_Toledo_0038.jpg
# 파일 이동 완료 : Jake_Plummer_0001.jpg
# 파일 이동 완료 : John_Edwards_0002.jpg
# 파일 이동 완료 : Christian_Patino_0001.jpg
# 파일 이동 완료 : Russell_Crowe_0002.jpg
# 파일 이동 완료 : Tina_Fey_0001.jpg
# 파일 이동 완료 : Martina_Hingis_0002.jpg
# 파일 이동 완료 : Gabrielle_Union_0001.jpg
# 파일 이동 완료 : Christian_Olsson_0001.jpg
# 파일 이동 완료 : Alexandra_Spann_0001.jpg
# 파일 이동 완료 : Abdullah_0004.jpg
# 파일 이동 완료 : Francis_George_0001.jpg
# 파일 이동 완료 : Andre_Agassi_0013.jpg
# 파일 이동 완료 : Greg_Hodge_0001.jpg
# 파일 이동 완료 : Colin_Powell_0047.jpg
# 파일 이동 완료 : Walid_Al-Awadi_0001.jpg
# 파일 이동 완료 : Elizabeth_Smart_0001.jpg
# 파일 이동 완료 : Lennox_Lewis_0002.jpg
# 파일 이동 완료 : Julie_Gerberding_0004.jpg
# 파일 이동 완료 : Hans_Blix_0035.jpg
# 파일 이동 완료 : George_Robertson_0014.jpg
# 파일 이동 완료 : George_W_Bush_0050.jpg
# 파일 이동 완료 : Suzanne_Mubarak_0001.jpg
# 파일 이동 완료 : Curtis_Rodriguez_0001.jpg
# 파일 이동 완료 : Saied_Hadi_al_Mudarissi_0001.jpg
# 파일 이동 완료 : Donna_Brazile_0001.jpg
# 파일 이동 완료 : Noer_Muis_0001.jpg
# 파일 이동 완료 : Dana_Vollmer_0001.jpg
# 파일 이동 완료 : Trent_Lott_0011.jpg
# 파일 이동 완료 : George_W_Bush_0165.jpg
# 파일 이동 완료 : James_Carville_0001.jpg
# 파일 이동 완료 : Steven_Craig_0001.jpg
# 파일 이동 완료 : Dennis_Powell_0002.jpg
# 파일 이동 완료 : Zhong_Nanshan_0001.jpg
# 파일 이동 완료 : JC_Chasez_0001.jpg
# 파일 이동 완료 : George_W_Bush_0430.jpg
# 파일 이동 완료 : Larry_Bowa_0002.jpg
# 파일 이동 완료 : Jessica_Brungo_0001.jpg
# 파일 이동 완료 : Paola_Espinoza_0001.jpg
# 파일 이동 완료 : Donald_Rumsfeld_0054.jpg
# 파일 이동 완료 : Sergei_Ivanov_0004.jpg
# 파일 이동 완료 : Tony_Blair_0016.jpg
# 파일 이동 완료 : George_W_Bush_0190.jpg
# 파일 이동 완료 : John_Snow_0001.jpg
# 파일 이동 완료 : Laurent_Jalabert_0001.jpg
# 파일 이동 완료 : Steve_Ballmer_0001.jpg
# 파일 이동 완료 : Jose_Bove_0001.jpg
# 파일 이동 완료 : Bob_Melvin_0001.jpg
# 파일 이동 완료 : Donald_Rumsfeld_0001.jpg
# 파일 이동 완료 : Rick_Perry_0003.jpg
# 파일 이동 완료 : Michael_J_Fox_0001.jpg
# 파일 이동 완료 : Tim_Matheson_0001.jpg
# 파일 이동 완료 : Julie_Gerberding_0006.jpg
# 파일 이동 완료 : Carlos_Menem_0012.jpg
# 파일 이동 완료 : Roh_Moo-hyun_0005.jpg
# 파일 이동 완료 : Sarah_Jessica_Parker_0004.jpg
# 파일 이동 완료 : Samuel_Waksal_0003.jpg
# 파일 이동 완료 : Denise_van_Outen_0001.jpg
# 파일 이동 완료 : Guillermo_Coria_0024.jpg
# 파일 이동 완료 : James_Wolfensohn_0005.jpg
# 파일 이동 완료 : Alberto_Acosta_0001.jpg
# 파일 이동 완료 : Scott_Peterson_0004.jpg
# 파일 이동 완료 : Hillary_Clinton_0003.jpg
# 파일 이동 완료 : John_Manley_0004.jpg
# 파일 이동 완료 : George_W_Bush_0489.jpg
# 파일 이동 완료 : Jelena_Dokic_0008.jpg
# 파일 이동 완료 : Danny_Elfman_0001.jpg
# 파일 이동 완료 : Gloria_Macapagal_Arroyo_0030.jpg
# 파일 이동 완료 : Nick_Rimando_0001.jpg
# 파일 이동 완료 : George_W_Bush_0117.jpg
# 파일 이동 완료 : George_W_Bush_0458.jpg
# 파일 이동 완료 : Laurie_Chan_0001.jpg
# 파일 이동 완료 : George_Voinovich_0003.jpg
# 파일 이동 완료 : Gina_Centrello_0001.jpg
# 파일 이동 완료 : Silvio_Berlusconi_0010.jpg
# 파일 이동 완료 : Mark_Philippoussis_0003.jpg
# 파일 이동 완료 : Herb_Sendek_0001.jpg
# 파일 이동 완료 : Rob_Marshall_0005.jpg
# 파일 이동 완료 : Michael_Bloomberg_0016.jpg
# 파일 이동 완료 : Kofi_Annan_0003.jpg
# 파일 이동 완료 : Joxel_Garcia_0001.jpg
# 파일 이동 완료 : John_Ashcroft_0017.jpg
# 파일 이동 완료 : Cyndi_Thompson_0002.jpg
# 파일 이동 완료 : Norm_Coleman_0002.jpg
# 파일 이동 완료 : Colleen_Ryan_0001.jpg
# 파일 이동 완료 : Juan_Carlos_Ferrero_0012.jpg
# 파일 이동 완료 : Elsa_Zylberstein_0005.jpg
# 파일 이동 완료 : Noelle_Bush_0001.jpg
# 파일 이동 완료 : Willie_Wilson_0001.jpg
# 파일 이동 완료 : Michael_Bloomberg_0017.jpg
# 파일 이동 완료 : Karin_Stoiber_0001.jpg
# 파일 이동 완료 : Martin_McGuinness_0001.jpg
# 파일 이동 완료 : Robbie_Mc_Ewen_0001.jpg
# 파일 이동 완료 : Dany_Heatley_0001.jpg
# 파일 이동 완료 : John_Kerry_0012.jpg
# 파일 이동 완료 : Christopher_Matero_0001.jpg
# 파일 이동 완료 : Sharon_Stone_0002.jpg
# 파일 이동 완료 : Hugh_Campbell_0001.jpg
# 파일 이동 완료 : Martha_Stewart_0004.jpg
# 파일 이동 완료 : George_W_Bush_0387.jpg
# 파일 이동 완료 : Hans_Blix_0039.jpg
# 파일 이동 완료 : Steve_Alford_0001.jpg
# 파일 이동 완료 : Monique_Gagnon-Tremblay_0001.jpg
# 파일 이동 완료 : Saman_Shali_0001.jpg
# 파일 이동 완료 : George_W_Bush_0429.jpg
# 파일 이동 완료 : Enola_Rice_0001.jpg
# 파일 이동 완료 : Bob_Hope_0002.jpg
# 파일 이동 완료 : Brad_Garrett_0003.jpg
# 파일 이동 완료 : Ismail_Abu_Shanab_0001.jpg
# 파일 이동 완료 : Hee-Won_Han_0001.jpg
# 파일 이동 완료 : Mark_Schweiker_0001.jpg
# 파일 이동 완료 : Luiz_Inacio_Lula_da_Silva_0020.jpg
# 파일 이동 완료 : Jennifer_Renee_Short_0001.jpg
# 파일 이동 완료 : Gary_Doer_0003.jpg
# 파일 이동 완료 : Colin_Powell_0068.jpg
# 파일 이동 완료 : Carla_Moreno_0001.jpg
# 파일 이동 완료 : Lisa_Stone_0001.jpg
# 파일 이동 완료 : Sean_OKeefe_0001.jpg
# 파일 이동 완료 : Herman_Moore_0001.jpg
# 파일 이동 완료 : George_W_Bush_0488.jpg
# 파일 이동 완료 : Jan_Ullrich_0006.jpg
# 파일 이동 완료 : Kitin_Munoz_0001.jpg
# 파일 이동 완료 : Mahmoud_Abbas_0029.jpg
# 파일 이동 완료 : Pat_Wharton_0001.jpg
# 파일 이동 완료 : Patrick_Rafter_0001.jpg
# 파일 이동 완료 : Queen_Elizabeth_II_0013.jpg
# 파일 이동 완료 : Carla_Gay_Balingit_0001.jpg
# 파일 이동 완료 : Iain_Duncan_Smith_0004.jpg
# 파일 이동 완료 : John_Gordnick_0001.jpg
# 파일 이동 완료 : Rudy_Tomjanovich_0001.jpg
# 파일 이동 완료 : Jose_Carreras_0001.jpg
# 파일 이동 완료 : Catherine_Zeta-Jones_0008.jpg
# 파일 이동 완료 : Tony_Blair_0027.jpg
# 파일 이동 완료 : Keith_Bishop_Jr_0001.jpg
# 파일 이동 완료 : Ana_Guevara_0007.jpg
# 파일 이동 완료 : Queen_Beatrix_0001.jpg
# 파일 이동 완료 : Wayne_Gretzky_0002.jpg
# 파일 이동 완료 : Mike_Bryan_0001.jpg
# 파일 이동 완료 : Eva_Dimas_0002.jpg
# 파일 이동 완료 : Arnold_Scott_0001.jpg
# 파일 이동 완료 : Brent_Coles_0001.jpg
# 파일 이동 완료 : Rupert_Grint_0003.jpg
# 파일 이동 완료 : Roh_Moo-hyun_0025.jpg
# 파일 이동 완료 : George_W_Bush_0358.jpg
# 파일 이동 완료 : Masum_Turker_0002.jpg
# 파일 이동 완료 : Jennifer_Aniston_0004.jpg
# 파일 이동 완료 : Mike_Tyson_0001.jpg
# 파일 이동 완료 : Wanda_de_la_Jesus_0001.jpg
# 파일 이동 완료 : Patricia_Russo_0001.jpg
# 파일 이동 완료 : Jamie_Villafane_0001.jpg
# 파일 이동 완료 : Monte_Kiffin_0001.jpg
# 파일 이동 완료 : Lauren_Killian_0002.jpg
# 파일 이동 완료 : Jacques_Rogge_0008.jpg
# 파일 이동 완료 : Clint_Lamebear_0001.jpg
# 파일 이동 완료 : Li_Peng_0006.jpg
# 파일 이동 완료 : Colin_Powell_0222.jpg
# 파일 이동 완료 : Tony_Blair_0014.jpg
# 파일 이동 완료 : Donald_Pettit_0001.jpg
# 파일 이동 완료 : Andrew_Bernard_0001.jpg
# 파일 이동 완료 : Rand_Beers_0001.jpg
# 파일 이동 완료 : Jason_Jennings_0002.jpg
# 파일 이동 완료 : Steve_Mariucci_0002.jpg
# 파일 이동 완료 : Costas_Simitis_0004.jpg
# 파일 이동 완료 : Jean-Pierre_Raffarin_0003.jpg
# 파일 이동 완료 : George_W_Bush_0266.jpg
# 파일 이동 완료 : Aleksander_Kwasniewski_0001.jpg
# 파일 이동 완료 : Ricardo_Sanchez_0002.jpg
# 파일 이동 완료 : Gloria_Macapagal_Arroyo_0028.jpg
# 파일 이동 완료 : Donald_Rumsfeld_0081.jpg
# 파일 이동 완료 : Princess_Stephanie_0001.jpg
# 파일 이동 완료 : Mireya_Moscoso_0004.jpg
# 파일 이동 완료 : Johnny_Depp_0001.jpg
# 파일 이동 완료 : Glenn_Plummer_0001.jpg
# 파일 이동 완료 : Gerry_Kelly_0001.jpg
# 파일 이동 완료 : Susan_Sarandon_0006.jpg
# 파일 이동 완료 : Anna_Chicherova_0001.jpg
# 파일 이동 완료 : Dennis_Miller_0001.jpg
# 파일 이동 완료 : Mike_Brey_0002.jpg
# 파일 이동 완료 : Tom_Harkin_0003.jpg
# 파일 이동 완료 : Aitor_Gonzalez_0002.jpg
# 파일 이동 완료 : Dave_Potter_0001.jpg
# 파일 이동 완료 : Nicole_Kidman_0008.jpg
# 파일 이동 완료 : Alexa_Loren_0001.jpg
# 파일 이동 완료 : Jennifer_Capriati_0004.jpg
# 파일 이동 완료 : Mathias_Reichhold_0002.jpg
# 파일 이동 완료 : Marco_Antonio_Barrera_0005.jpg
# 파일 이동 완료 : Jelena_Dokic_0001.jpg
# 파일 이동 완료 : Walter_Woods_0001.jpg
# 파일 이동 완료 : Joseph_LePore_0001.jpg
# 파일 이동 완료 : George_W_Bush_0492.jpg
# 파일 이동 완료 : Norodom_Sihanouk_0002.jpg
# 파일 이동 완료 : Jacqueline_Obradors_0002.jpg
# 파일 이동 완료 : Michael_Doleac_0001.jpg
# 파일 이동 완료 : Bob_Hope_0005.jpg
# 파일 이동 완료 : Carlos_Menem_0004.jpg
# 파일 이동 완료 : Sharon_Stone_0005.jpg
# 파일 이동 완료 : George_W_Bush_0325.jpg
# 파일 이동 완료 : Roger_Suarez_0001.jpg
# 파일 이동 완료 : Gray_Davis_0010.jpg
# 파일 이동 완료 : Xanana_Gusmao_0005.jpg
# 파일 이동 완료 : Jay_Rasulo_0002.jpg
# 파일 이동 완료 : Colin_Powell_0073.jpg
# 파일 이동 완료 : Pete_Sampras_0006.jpg
# 파일 이동 완료 : Jennifer_Lopez_0018.jpg
# 파일 이동 완료 : Gordon_Lightfoot_0001.jpg
# 파일 이동 완료 : Colin_Powell_0211.jpg
# 파일 이동 완료 : Randy_Brown_0001.jpg
# 파일 이동 완료 : Scott_McClellan_0002.jpg
# 파일 이동 완료 : Vicki_Zhao_Wei_0001.jpg
# 파일 이동 완료 : Winona_Ryder_0004.jpg
# 파일 이동 완료 : Meryl_Streep_0014.jpg
# 파일 이동 완료 : George_W_Bush_0224.jpg
# 파일 이동 완료 : Kim_Clijsters_0007.jpg
# 파일 이동 완료 : Kathryn_Grayson_0001.jpg
# 파일 이동 완료 : John_Ashcroft_0053.jpg
# 파일 이동 완료 : Jean-Francois_Lemounier_0001.jpg
# 파일 이동 완료 : Cameron_Diaz_0006.jpg
# 파일 이동 완료 : Jim_OBrien_0002.jpg
# 파일 이동 완료 : Hamid_Karzai_0013.jpg
# 파일 이동 완료 : Ben_Kingsley_0001.jpg
# 파일 이동 완료 : Kai-Uwe_Ricke_0001.jpg
# 파일 이동 완료 : Stefan_Tafrov_0001.jpg
# 파일 이동 완료 : Clint_Eastwood_0005.jpg
# 파일 이동 완료 : Angela_Bassett_0006.jpg
# 파일 이동 완료 : Venus_Williams_0012.jpg
# 파일 이동 완료 : Tino_Martinez_0001.jpg
# 파일 이동 완료 : Tung_Chee-hwa_0003.jpg
# 파일 이동 완료 : Jana_Pittman_0001.jpg
# 파일 이동 완료 : Spike_Jonze_0001.jpg
# 파일 이동 완료 : Gillian_Anderson_0002.jpg
# 파일 이동 완료 : Linda_Baboolal_0001.jpg
# 파일 이동 완료 : Talisa_Soto_0001.jpg
# 파일 이동 완료 : James_Blake_0003.jpg
# 파일 이동 완료 : Rachel_Hunter_0004.jpg
# 파일 이동 완료 : Chen_Shui-bian_0002.jpg
# 파일 이동 완료 : Bill_Doba_0001.jpg
# 파일 이동 완료 : Alejandro_Toledo_0028.jpg
# 파일 이동 완료 : George_W_Bush_0491.jpg
# 파일 이동 완료 : Paddy_Torsney_0001.jpg
# 파일 이동 완료 : Ralph_Klein_0001.jpg
# 파일 이동 완료 : Atal_Bihari_Vajpayee_0024.jpg
# 파일 이동 완료 : Gordon_Brown_0008.jpg
# 파일 이동 완료 : Avril_Lavigne_0001.jpg
# 파일 이동 완료 : Terry_Hoeppner_0001.jpg
# 파일 이동 완료 : Paradorn_Srichaphan_0009.jpg
# 파일 이동 완료 : Robert_Redford_0007.jpg
# 파일 이동 완료 : Paul_Burrell_0008.jpg
# 파일 이동 완료 : Gerhard_Schroeder_0003.jpg
# 파일 이동 완료 : Kim_Ryong-sung_0007.jpg
# 파일 이동 완료 : Jean_Charest_0005.jpg
# 파일 이동 완료 : Cathy_Freeman_0002.jpg
# 파일 이동 완료 : Abdel_Madi_Shabneh_0001.jpg
# 파일 이동 완료 : Jennifer_Capriati_0042.jpg
# 파일 이동 완료 : Frank_Bell_0001.jpg
# 파일 이동 완료 : Jeb_Bush_0011.jpg
# 파일 이동 완료 : Atal_Bihari_Vajpayee_0016.jpg
# 파일 이동 완료 : Yang_Hee_Kim_0001.jpg
# 파일 이동 완료 : Mireya_Moscoso_0002.jpg
# 파일 이동 완료 : Lili_Taylor_0001.jpg
# 파일 이동 완료 : Zinedine_Zidane_0006.jpg
# 파일 이동 완료 : George_W_Bush_0520.jpg
# 파일 이동 완료 : Paul_Bremer_0005.jpg
# 파일 이동 완료 : Natalia_Dmitrieva_0001.jpg
# 파일 이동 완료 : Michael_Caine_0002.jpg
# 파일 이동 완료 : David_McCullough_0001.jpg
# 파일 이동 완료 : Blythe_Hartley_0001.jpg
# 파일 이동 완료 : Pringe_Ernst_August_0001.jpg
# 파일 이동 완료 : Lindsay_Davenport_0001.jpg
# 파일 이동 완료 : Bill_Clinton_0020.jpg
# 파일 이동 완료 : Isaiah_Washington_0002.jpg
# 파일 이동 완료 : Harrison_Ford_0012.jpg
# 파일 이동 완료 : Vladimir_Putin_0012.jpg
# 파일 이동 완료 : Jose_Acasuso_0001.jpg
# 파일 이동 완료 : Jane_Rooney_0001.jpg
# 파일 이동 완료 : Luiz_Inacio_Lula_da_Silva_0041.jpg
# 파일 이동 완료 : Jeremy_Greenstock_0010.jpg
# 파일 이동 완료 : Celine_Dion_0002.jpg
# 파일 이동 완료 : Jennie_Finch_0001.jpg
# 파일 이동 완료 : Sophia_Loren_0006.jpg
# 파일 이동 완료 : Fernando_Gonzalez_0009.jpg
# 파일 이동 완료 : George_W_Bush_0220.jpg
# 파일 이동 완료 : Ernie_Els_0002.jpg
# 파일 이동 완료 : George_W_Bush_0216.jpg
# 파일 이동 완료 : Raja_Zafar-ul-Haq_0001.jpg
# 파일 이동 완료 : Horace_Donovan_Reid_0001.jpg
# 파일 이동 완료 : Sylvester_Stallone_0007.jpg
# 파일 이동 완료 : Mitchell_Daniels_0003.jpg
# 파일 이동 완료 : Nestor_Kirchner_0010.jpg
# 파일 이동 완료 : John_Barnett_0001.jpg
# 파일 이동 완료 : Grant_Hackett_0005.jpg
# 파일 이동 완료 : Jimmy_Lee_0001.jpg
# 파일 이동 완료 : Cecilia_Bolocco_0003.jpg
# 파일 이동 완료 : Charles_Holzner_0001.jpg
# 파일 이동 완료 : David_Hilt_0001.jpg
# 파일 이동 완료 : Amelie_Mauresmo_0021.jpg
# 파일 이동 완료 : Jawad_Boulus_0001.jpg
# 파일 이동 완료 : Lleyton_Hewitt_0010.jpg
# 파일 이동 완료 : Ibrahim_Haddad_0001.jpg
# 파일 이동 완료 : Jimmy_Carter_0001.jpg
# 파일 이동 완료 : Arlen_Specter_0002.jpg
# 파일 이동 완료 : Muhammad_Ali_0004.jpg
# 파일 이동 완료 : Darko_Milicic_0001.jpg
# 파일 이동 완료 : Joseph_Ganim_0001.jpg
# 파일 이동 완료 : Amer_al-Saadi_0003.jpg
# 파일 이동 완료 : Damarius_Bilbo_0001.jpg
# 파일 이동 완료 : Wen_Jiabao_0011.jpg
# 파일 이동 완료 : Peter_Hillary_0001.jpg
# 파일 이동 완료 : Ethan_Hawke_0003.jpg
# 파일 이동 완료 : Penelope_Cruz_0002.jpg
# 파일 이동 완료 : Richard_Crenna_0001.jpg
# 파일 이동 완료 : Herb_Sendek_0002.jpg
# 파일 이동 완료 : Leonardo_DiCaprio_0008.jpg
# 파일 이동 완료 : Igor_Ivanov_0003.jpg
# 파일 이동 완료 : Katherine_Harris_0004.jpg
# 파일 이동 완료 : Elizabeth_Dole_0001.jpg
# 파일 이동 완료 : Evander_Holyfield_0001.jpg
# 파일 이동 완료 : Oscar_Bolanos_0001.jpg
# 파일 이동 완료 : Steve_Nash_0004.jpg
# 파일 이동 완료 : Megawati_Sukarnoputri_0012.jpg
# 파일 이동 완료 : Tony_Blair_0077.jpg
# 파일 이동 완료 : Gerhard_Schroeder_0024.jpg
# 파일 이동 완료 : Mo_Elleithee_0001.jpg
# 파일 이동 완료 : Tatiana_Paus_0001.jpg
# 파일 이동 완료 : Roh_Moo-hyun_0031.jpg
# 파일 이동 완료 : Jason_Priestley_0001.jpg
# 파일 이동 완료 : Alexander_Losyukov_0004.jpg
# 파일 이동 완료 : Michael_Taylor_0001.jpg
# 파일 이동 완료 : Infanta_Cristina_0001.jpg
# 파일 이동 완료 : Amy_Brenneman_0001.jpg
# 파일 이동 완료 : Colin_Farrell_0007.jpg
# 파일 이동 완료 : Lance_Bass_0003.jpg
# 파일 이동 완료 : Carolina_Barco_0001.jpg
# 파일 이동 완료 : Nestor_Santillan_0001.jpg
# 파일 이동 완료 : Anthony_Rackauckas_0001.jpg
# 파일 이동 완료 : John_Ashcroft_0016.jpg
# 파일 이동 완료 : Branko_Crvenkovski_0001.jpg
# 파일 이동 완료 : Amer_al-Saadi_0004.jpg
# 파일 이동 완료 : Serena_Williams_0030.jpg
# 파일 이동 완료 : Yao_Ming_0008.jpg
# 파일 이동 완료 : George_W_Bush_0348.jpg
# 파일 이동 완료 : Tracee_Treadwell_0001.jpg
# 파일 이동 완료 : Mike_Weir_0009.jpg
# 파일 이동 완료 : Julianne_Moore_0017.jpg
# 파일 이동 완료 : Sherry_Fisher_0001.jpg
# 파일 이동 완료 : Luiz_Inacio_Lula_da_Silva_0028.jpg
# 파일 이동 완료 : Erwin_Mapasseng_0001.jpg
# 파일 이동 완료 : Jose_Serra_0009.jpg
# 파일 이동 완료 : Keanu_Reeves_0012.jpg
# 파일 이동 완료 : Mikhail_Youzhny_0003.jpg
# 파일 이동 완료 : Nick_Nolte_0004.jpg
# 파일 이동 완료 : Marina_Anissina_0002.jpg
# 파일 이동 완료 : Todd_MacCulloch_0001.jpg
# 파일 이동 완료 : Doug_Racine_0001.jpg
# 파일 이동 완료 : Bob_Stoops_0001.jpg
# 파일 이동 완료 : GL_Peiris_0003.jpg
# 파일 이동 완료 : Nathalie_Baye_0001.jpg
# 파일 이동 완료 : Brawley_King_0001.jpg
# 파일 이동 완료 : Hillary_Clinton_0002.jpg
# 파일 이동 완료 : Fujio_Mitarai_0001.jpg
# 파일 이동 완료 : Tony_Blair_0008.jpg
# 파일 이동 완료 : Ben_Betts_0001.jpg
# 파일 이동 완료 : Uri_Lopolianski_0001.jpg
# 파일 이동 완료 : Eric_Ryan_Donnelly_0001.jpg
# 파일 이동 완료 : Carlos_Moya_0010.jpg
# 파일 이동 완료 : Raoul_Ruiz_0003.jpg
# 파일 이동 완료 : Franz_Gsell_0001.jpg
# 파일 이동 완료 : Pierce_Brosnan_0008.jpg
# 파일 이동 완료 : Lleyton_Hewitt_0033.jpg
# 파일 이동 완료 : Michel_Duclos_0002.jpg
# 파일 이동 완료 : Kellie_Coffey_0001.jpg
# 파일 이동 완료 : Colin_Powell_0003.jpg
# 파일 이동 완료 : Reggie_Lewis_0001.jpg
# 파일 이동 완료 : Jada_Pinkett_Smith_0001.jpg
# 파일 이동 완료 : Keith_Fotta_0001.jpg
# 파일 이동 완료 : Fernando_Hierro_0001.jpg
# 파일 이동 완료 : Bob_Geldof_0001.jpg
# 파일 이동 완료 : Tom_Cruise_0007.jpg
# 파일 이동 완료 : Mark_Redman_0001.jpg
# 파일 이동 완료 : Daniela_Hantuchova_0002.jpg
# 파일 이동 완료 : Roy_Moore_0004.jpg
# 파일 이동 완료 : Todd_Haynes_0001.jpg
# 파일 이동 완료 : Britney_Spears_0005.jpg
# 파일 이동 완료 : Christine_Todd_Whitman_0001.jpg
# 파일 이동 완료 : Jeane_Kirkpatrick_0001.jpg
# 파일 이동 완료 : Frank_Griswold_0001.jpg
# 파일 이동 완료 : Rosemarie_Stack_0002.jpg
# 파일 이동 완료 : Luciano_Pavarotti_0003.jpg
# 파일 이동 완료 : Laura_Bush_0021.jpg
# 파일 이동 완료 : Peter_Albertsen_0001.jpg
# 파일 이동 완료 : Colin_Powell_0031.jpg
# 파일 이동 완료 : Holly_Hunter_0003.jpg
# 파일 이동 완료 : Laura_Bush_0033.jpg
# 파일 이동 완료 : James_Blake_0009.jpg
# 파일 이동 완료 : Jimmy_Gurule_0001.jpg
# 파일 이동 완료 : Sananda_Maitreya_0001.jpg
# 파일 이동 완료 : Al_Sharpton_0001.jpg
# 파일 이동 완료 : Chris_Kolanas_0001.jpg
# 파일 이동 완료 : Dunn_Lampton_0001.jpg
# 파일 이동 완료 : Don_Henley_0001.jpg
# 파일 이동 완료 : Yoko_Ono_0001.jpg
# 파일 이동 완료 : Spike_Helmick_0001.jpg
# 파일 이동 완료 : Jack_Straw_0012.jpg
# 파일 이동 완료 : Jean-Marc_de_La_Sabliere_0001.jpg
# 파일 이동 완료 : Gerard_Butler_0001.jpg
# 파일 이동 완료 : Ismail_Khan_0001.jpg
# 파일 이동 완료 : George_W_Bush_0467.jpg
# 파일 이동 완료 : Buck_Rodgers_0001.jpg
# 파일 이동 완료 : George_Ryan_0001.jpg
# 파일 이동 완료 : Norah_Jones_0003.jpg
# 파일 이동 완료 : Joseph_Hoy_0001.jpg
# 파일 이동 완료 : Roberto_Tovar_0001.jpg
# 파일 이동 완료 : James_Coburn_0001.jpg
# 파일 이동 완료 : Junichiro_Koizumi_0031.jpg
# 파일 이동 완료 : Estelle_Morris_0001.jpg
# 파일 이동 완료 : Jean_Chretien_0011.jpg
# 파일 이동 완료 : Colin_Powell_0078.jpg
# 파일 이동 완료 : Bertrand_Bonello_0002.jpg
# 파일 이동 완료 : Peter_Fonda_0001.jpg
# 파일 이동 완료 : Jaime_Pressly_0001.jpg
# 파일 이동 완료 : Gerhard_Schroeder_0049.jpg
# 파일 이동 완료 : Pupi_Avati_0002.jpg
# 파일 이동 완료 : Andres_Pastrana_0001.jpg
# 파일 이동 완료 : Guillermo_Ortiz_0002.jpg
# 파일 이동 완료 : Teresa_Graves_0001.jpg
# 파일 이동 완료 : Greg_Ostertag_0002.jpg
# 파일 이동 완료 : Sharon_Osbourne_0003.jpg
# 파일 이동 완료 : Gloria_Macapagal_Arroyo_0001.jpg
# 파일 이동 완료 : Kofi_Annan_0001.jpg
# 파일 이동 완료 : Tommy_Haas_0003.jpg
# 파일 이동 완료 : Jose_Maria_Aznar_0021.jpg
# 파일 이동 완료 : George_Lopez_0002.jpg
# 파일 이동 완료 : Lance_Armstrong_0004.jpg
# 파일 이동 완료 : David_Stern_0003.jpg
# 파일 이동 완료 : Michael_Schumacher_0013.jpg
# 파일 이동 완료 : David_Brent_0001.jpg
# 파일 이동 완료 : Michael_Chang_0008.jpg
# 파일 이동 완료 : Benjamin_Franklin_0001.jpg
# 파일 이동 완료 : Colin_Powell_0060.jpg
# 파일 이동 완료 : John_Rosa_0002.jpg
# 파일 이동 완료 : Amram_Mitzna_0001.jpg
# 파일 이동 완료 : McGuire_Gibson_0001.jpg
# 파일 이동 완료 : Mark_Rosenbaum_0001.jpg
# 파일 이동 완료 : Charles_Taylor_0004.jpg
# 파일 이동 완료 : Carroll_Weimer_0001.jpg
# 파일 이동 완료 : Dolma_Tsering_0001.jpg
# 파일 이동 완료 : Greg_Gilbert_0001.jpg
# 파일 이동 완료 : Fidel_Castro_0002.jpg
# 파일 이동 완료 : Alvaro_Uribe_0003.jpg
# 파일 이동 완료 : Meghann_Shaughnessy_0001.jpg
# 파일 이동 완료 : Recep_Tayyip_Erdogan_0004.jpg
# 파일 이동 완료 : Joan_Laporta_0001.jpg
# 파일 이동 완료 : Mahmoud_Abbas_0006.jpg
# 파일 이동 완료 : Tim_Conway_0001.jpg
# 파일 이동 완료 : Rita_Grande_0001.jpg
# 파일 이동 완료 : Ari_Fleischer_0012.jpg
# 파일 이동 완료 : Larry_Anderson_0001.jpg
# 파일 이동 완료 : Christopher_Speer_0001.jpg
# 파일 이동 완료 : Jaouad_Gharib_0001.jpg
# 파일 이동 완료 : Ellen_DeGeneres_0002.jpg
# 파일 이동 완료 : Chris_Terry_0001.jpg
# 파일 이동 완료 : Joe_Calzaghe_0001.jpg
# 파일 이동 완료 : Jean-Claude_Braquet_0001.jpg
# 파일 이동 완료 : Jim_Hahn_0002.jpg
# 파일 이동 완료 : Ahmed_Chalabi_0005.jpg
# 파일 이동 완료 : Duane_Barber_0001.jpg
# 파일 이동 완료 : Lucrecia_Orozco_0001.jpg
# 파일 이동 완료 : Jorge_Batlle_0002.jpg
# 파일 이동 완료 : Keith_Rodriguez_0001.jpg
# 파일 이동 완료 : Ratna_Sari_Dewi_Sukarno_0001.jpg
# 파일 이동 완료 : Arnold_Schwarzenegger_0001.jpg
# 파일 이동 완료 : Natasha_Lyonne_0001.jpg
# 파일 이동 완료 : John_Abizaid_0005.jpg
# 파일 이동 완료 : Taha_Yassin_Ramadan_0003.jpg
# 파일 이동 완료 : David_Trimble_0005.jpg
# 파일 이동 완료 : Ken_Kutaragi_0001.jpg
# 파일 이동 완료 : Jenny_Romero_0001.jpg
# 파일 이동 완료 : Brian_Wells_0002.jpg
# 파일 이동 완료 : Junichiro_Koizumi_0009.jpg
# 파일 이동 완료 : Natalie_Maines_0005.jpg
# 파일 이동 완료 : Richard_Gere_0005.jpg
# 파일 이동 완료 : Carly_Fiorina_0003.jpg
# 파일 이동 완료 : Doug_Melvin_0001.jpg
# 파일 이동 완료 : Eric_Lloyd_0001.jpg
# 파일 이동 완료 : John_Engler_0001.jpg
# 파일 이동 완료 : Mario_Vasquez_Rana_0001.jpg
# 파일 이동 완료 : Nelson_Mandela_0002.jpg
# 파일 이동 완료 : Geoff_Hoon_0004.jpg
# 파일 이동 완료 : Monica_Lewinsky_0001.jpg
# 파일 이동 완료 : Kosuke_Kitajima_0002.jpg
# 파일 이동 완료 : Jorge_Arce_0001.jpg
# 파일 이동 완료 : Ben_Braun_0001.jpg
# 파일 이동 완료 : Lleyton_Hewitt_0034.jpg
# 파일 이동 완료 : Bill_Gates_0008.jpg
# 파일 이동 완료 : Javier_Weber_0003.jpg
# 파일 이동 완료 : Valdas_Adamkus_0001.jpg
# 파일 이동 완료 : Choi_Sung-hong_0003.jpg
# 파일 이동 완료 : Penelope_Cruz_0001.jpg
# 파일 이동 완료 : Jon_Gruden_0003.jpg
# 파일 이동 완료 : Peter_Harrison_0002.jpg
# 파일 이동 완료 : Jean-David_Levitte_0005.jpg
# 파일 이동 완료 : Stephanie_Cohen_Aloro_0001.jpg
# 파일 이동 완료 : Denise_Locke_0001.jpg
# 파일 이동 완료 : John_Howard_0003.jpg
# 파일 이동 완료 : Bob_Graham_0001.jpg
# 파일 이동 완료 : Lou_Piniella_0001.jpg
# 파일 이동 완료 : Ray_Allen_0003.jpg
# 파일 이동 완료 : Lesley_Coppin_0001.jpg
# 파일 이동 완료 : Gerhard_Schroeder_0029.jpg
# 파일 이동 완료 : Rob_Lowe_0003.jpg
# 파일 이동 완료 : Red_Auerbach_0001.jpg
# 파일 이동 완료 : Corinne_Coman_0001.jpg
# 파일 이동 완료 : Eric_Staal_0001.jpg
# 파일 이동 완료 : Megawati_Sukarnoputri_0029.jpg
# 파일 이동 완료 : George_Foreman_0001.jpg
# 파일 이동 완료 : Celine_Dion_0001.jpg
# 파일 이동 완료 : Rena_Sofer_0001.jpg
# 파일 이동 완료 : Kim_Clijsters_0009.jpg
# 파일 이동 완료 : Carmen_Electra_0004.jpg
# 파일 이동 완료 : Julianne_Moore_0007.jpg
# 파일 이동 완료 : Michelle_Kwan_0005.jpg
# 파일 이동 완료 : Jimmy_Szymanski_0001.jpg
# 파일 이동 완료 : Poala_Suarez_0001.jpg
# 파일 이동 완료 : Ashton_Kutcher_0002.jpg
# 파일 이동 완료 : Tony_Blair_0024.jpg
# 파일 이동 완료 : Robert_Mueller_0003.jpg
# 파일 이동 완료 : Joschka_Fischer_0018.jpg
# 파일 이동 완료 : Carol_Carmody_0001.jpg
# 파일 이동 완료 : Vincent_Brooks_0002.jpg
# 파일 이동 완료 : Jean-Claude_Juncker_0002.jpg
# 파일 이동 완료 : Dominique_de_Villepin_0009.jpg
# 파일 이동 완료 : Serena_Williams_0020.jpg
# 파일 이동 완료 : Gunter_Pleuger_0001.jpg
# 파일 이동 완료 : Luiz_Inacio_Lula_da_Silva_0002.jpg
# 파일 이동 완료 : Tim_Henman_0007.jpg
# 파일 이동 완료 : Luiz_Inacio_Lula_da_Silva_0006.jpg
# 파일 이동 완료 : John_Bolton_0014.jpg
# 파일 이동 완료 : Kim_Ryong-sung_0004.jpg
# 파일 이동 완료 : Hillary_Clinton_0012.jpg
# 파일 이동 완료 : Igor_Ivanov_0017.jpg
# 파일 이동 완료 : Felipe_Fernandez_0001.jpg
# 파일 이동 완료 : Laura_Bush_0007.jpg
# 파일 이동 완료 : Clifford_Robinson_0001.jpg
# 파일 이동 완료 : Jean-Luc_Bideau_0001.jpg
# 파일 이동 완료 : Ludivine_Sagnier_0002.jpg
# 파일 이동 완료 : Dave_Johnson_0001.jpg
# 파일 이동 완료 : Christine_Ebersole_0001.jpg
# 파일 이동 완료 : Jean_Nagel_0001.jpg
# 파일 이동 완료 : Phan_Van_Khai_0003.jpg
# 파일 이동 완료 : Kirk_Doerger_0001.jpg
# 파일 이동 완료 : TA_McLendon_0001.jpg
# 파일 이동 완료 : Jaymon_Crabb_0001.jpg
# 파일 이동 완료 : James_Morris_0002.jpg
# 파일 이동 완료 : Norah_Jones_0015.jpg
# 파일 이동 완료 : Hilary_Duff_0001.jpg
# 파일 이동 완료 : Osama_bin_Laden_0002.jpg
# 파일 이동 완료 : David_Hannay_0001.jpg
# 파일 이동 완료 : Nicole_Kidman_0007.jpg
# 파일 이동 완료 : Michael_Bloomberg_0010.jpg
# 파일 이동 완료 : Lucy_Liu_0004.jpg
# 파일 이동 완료 : Jeffrey_Scott_Postell_0001.jpg
# 파일 이동 완료 : George_W_Bush_0478.jpg
# 파일 이동 완료 : Michael_Chiklis_0003.jpg
# 파일 이동 완료 : Condoleezza_Rice_0006.jpg
# 파일 이동 완료 : Norman_Mailer_0001.jpg
# 파일 이동 완료 : Dave_McGinnis_0001.jpg
# 파일 이동 완료 : Hosni_Mubarak_0007.jpg
# 파일 이동 완료 : Keith_Bogans_0001.jpg
# 파일 이동 완료 : Rene_Antonio_Leon_Rodriguez_0001.jpg
# 파일 이동 완료 : Pierce_Brosnan_0002.jpg
# 파일 이동 완료 : Bruce_Springsteen_0004.jpg
# 파일 이동 완료 : Brandon_Lloyd_0001.jpg
# 파일 이동 완료 : Javier_Solana_0009.jpg
# 파일 이동 완료 : JK_Rowling_0005.jpg
# 파일 이동 완료 : Jean-Claude_Juncker_0001.jpg
# 파일 이동 완료 : Alvaro_Uribe_0033.jpg
# 파일 이동 완료 : Donald_Rumsfeld_0018.jpg
# 파일 이동 완료 : Tiger_Woods_0013.jpg
# 파일 이동 완료 : Abbas_Kiarostami_0001.jpg
# 파일 이동 완료 : Jon_Stewart_0001.jpg
# 파일 이동 완료 : Gerald_Barbarito_0001.jpg
# 파일 이동 완료 : Charles_Taylor_0001.jpg
# 파일 이동 완료 : Nestor_Kirchner_0011.jpg
# 파일 이동 완료 : Muammar_Gaddafi_0002.jpg
# 파일 이동 완료 : Fidel_Castro_0006.jpg
# 파일 이동 완료 : Chris_Thomas_0001.jpg
# 파일 이동 완료 : Zelma_Novelo_0001.jpg
# 파일 이동 완료 : Joan_Laporta_0008.jpg
# 파일 이동 완료 : George_W_Bush_0435.jpg
# 파일 이동 완료 : Paul-Henri_Mathieu_0002.jpg
# 파일 이동 완료 : Jesse_Jackson_0007.jpg
# 파일 이동 완료 : John_Robbins_0001.jpg
# 파일 이동 완료 : Peter_Caruana_0001.jpg
# 파일 이동 완료 : Jelena_Dokic_0002.jpg
# 파일 이동 완료 : Kang_Gum-sil_0001.jpg
# 파일 이동 완료 : Isabel_Orellana_0001.jpg
# 파일 이동 완료 : Albert_Pujols_0001.jpg
# 파일 이동 완료 : Colin_Montgomerie_0005.jpg
# 파일 이동 완료 : Bill_Graham_0007.jpg
# 파일 이동 완료 : Princess_Caroline_0004.jpg
# 파일 이동 완료 : Martha_Beatriz_Roque_0001.jpg
# 파일 이동 완료 : George_Galloway_0001.jpg
# 파일 이동 완료 : Aron_Ralston_0001.jpg
# 파일 이동 완료 : Hugh_Miller_0001.jpg
# 파일 이동 완료 : Tony_Blair_0042.jpg
# 파일 이동 완료 : Jan_Bjoerklund_0001.jpg
# 파일 이동 완료 : Armando_Calderon_Sol_0001.jpg
# 파일 이동 완료 : Vladimir_Putin_0038.jpg
# 파일 이동 완료 : Gray_Davis_0025.jpg
# 파일 이동 완료 : Dan_Morales_0001.jpg
# 파일 이동 완료 : Rick_Romley_0001.jpg
# 파일 이동 완료 : Colin_Powell_0076.jpg
# 파일 이동 완료 : Randy_Ferbey_0001.jpg
# 파일 이동 완료 : Mohammed_Salmane_0001.jpg
# 파일 이동 완료 : Michael_Chiklis_0001.jpg
# 파일 이동 완료 : Tiger_Woods_0012.jpg
# 파일 이동 완료 : Costas_Simitis_0001.jpg
# 파일 이동 완료 : Hugo_Chavez_0044.jpg
# 파일 이동 완료 : Gerhard_Schroeder_0011.jpg
# 파일 이동 완료 : Vladimiro_Montesinos_0001.jpg
# 파일 이동 완료 : Charles_Richardson_0001.jpg
# 파일 이동 완료 : Ryan_Leaf_0001.jpg
# 파일 이동 완료 : Susan_Sarandon_0005.jpg
# 파일 이동 완료 : Tom_Ridge_0014.jpg
# 파일 이동 완료 : Sammy_Sosa_0002.jpg
# 파일 이동 완료 : Kim_Dong-tae_0001.jpg
# 파일 이동 완료 : Lene_Espersen_0001.jpg
# 파일 이동 완료 : Tony_Fernandes_0001.jpg
# 파일 이동 완료 : Manuela_Montebrun_0001.jpg
# 파일 이동 완료 : Lisa_Ling_0001.jpg
# 파일 이동 완료 : Mark_Philippoussis_0007.jpg
# 파일 이동 완료 : Laura_Hernandez_0002.jpg
# 파일 이동 완료 : David_Spade_0001.jpg
# 파일 이동 완료 : Jennifer_Aniston_0014.jpg
# 파일 이동 완료 : Jayson_Williams_0001.jpg
# 파일 이동 완료 : James_Maguire_0001.jpg
# 파일 이동 완료 : Saddam_Hussein_0014.jpg
# 파일 이동 완료 : Frank_Hsieh_0001.jpg
# 파일 이동 완료 : Susan_Collins_0002.jpg
# 파일 이동 완료 : Rachel_Corrie_0001.jpg
# 파일 이동 완료 : John_Cruz_0001.jpg
# 파일 이동 완료 : Ruth_Pearce_0001.jpg
# 파일 이동 완료 : Ray_Romano_0008.jpg
# 파일 이동 완료 : Paul_Burrell_0003.jpg
# 파일 이동 완료 : Maura_Tierney_0001.jpg
# 파일 이동 완료 : Edmund_Stoiber_0002.jpg
# 파일 이동 완료 : Brad_Brownell_0001.jpg
# 파일 이동 완료 : Milo_Djukanovic_0003.jpg
# 파일 이동 완료 : Oswaldo_Paya_0002.jpg
# 파일 이동 완료 : Hisham_Halawi_0001.jpg
# 파일 이동 완료 : Art_Hoffmann_0002.jpg
# 파일 이동 완료 : Andre_Smith_0001.jpg
# 파일 이동 완료 : Oliver_Stone_0001.jpg
# 파일 이동 완료 : Hugo_Chavez_0063.jpg
# 파일 이동 완료 : Ignacio_Antonio_Velasco_0001.jpg
# 파일 이동 완료 : Geoffrey_Davis_0001.jpg
# 파일 이동 완료 : Pharrell_Williams_0001.jpg
# 파일 이동 완료 : Jeff_Van_Gundy_0002.jpg
# 파일 이동 완료 : Ricardo_Lagos_0008.jpg
# 파일 이동 완료 : Anthony_Corso_0001.jpg
# 파일 이동 완료 : James_Schultz_0002.jpg
# 파일 이동 완료 : Victoria_Beckham_0003.jpg
# 파일 이동 완료 : Masaru_Hayami_0001.jpg
# 파일 이동 완료 : George_W_Bush_0493.jpg
# 파일 이동 완료 : Michael_Jackson_0007.jpg
# 파일 이동 완료 : Colin_Powell_0001.jpg
# 파일 이동 완료 : John_Bolton_0017.jpg
# 파일 이동 완료 : George_W_Bush_0512.jpg
# 파일 이동 완료 : Tiger_Woods_0006.jpg
# 파일 이동 완료 : Jacques_Chirac_0038.jpg
# 파일 이동 완료 : Blas_Ople_0001.jpg
# 파일 이동 완료 : Brett_Boone_0001.jpg
# 파일 이동 완료 : Guy_Hemmings_0002.jpg
# 파일 이동 완료 : Gregg_Popovich_0004.jpg
# 파일 이동 완료 : Abdullah_Gul_0016.jpg
# 파일 이동 완료 : Naomi_Watts_0002.jpg
# 파일 이동 완료 : Thomas_Haeggstroem_0001.jpg
# 파일 이동 완료 : Britney_Spears_0006.jpg
# 파일 이동 완료 : Salman_Rushdie_0003.jpg
# 파일 이동 완료 : Norm_Macdonald_0001.jpg
# 파일 이동 완료 : Sergey_Lavrov_0011.jpg
# 파일 이동 완료 : Billy_Joel_0001.jpg
# 파일 이동 완료 : Mahathir_Mohamad_0012.jpg
# 파일 이동 완료 : Kim_Cattrall_0001.jpg
# 파일 이동 완료 : Zoe_Ball_0001.jpg
# 파일 이동 완료 : Franco_Dragone_0001.jpg
# 파일 이동 완료 : Lynn_Redgrave_0002.jpg
# 파일 이동 완료 : Jackie_Chan_0002.jpg
# 파일 이동 완료 : Ramiro_Goben_Reducindo_0001.jpg
# 파일 이동 완료 : Micky_Ward_0001.jpg
# 파일 이동 완료 : Donald_Rumsfeld_0082.jpg
# 파일 이동 완료 : Igor_Trunov_0001.jpg
# 파일 이동 완료 : Abdullah_Gul_0009.jpg
# 파일 이동 완료 : Kimberly_Stewart_0001.jpg
# 파일 이동 완료 : Yusaku_Miyazato_0001.jpg
# 파일 이동 완료 : George_W_Bush_0308.jpg
# 파일 이동 완료 : Colin_Powell_0025.jpg
# 파일 이동 완료 : William_Donaldson_0004.jpg
# 파일 이동 완료 : Fabrice_Santoro_0002.jpg
# 파일 이동 완료 : Albert_Costa_0005.jpg
# 파일 이동 완료 : Afton_Smith_0001.jpg
# 파일 이동 완료 : Steven_Spielberg_0002.jpg
# 파일 이동 완료 : Gerhard_Schroeder_0057.jpg
# 파일 이동 완료 : Chris_Whitney_0001.jpg
# 파일 이동 완료 : Yoko_Ono_0003.jpg
# 파일 이동 완료 : Arnold_Schwarzenegger_0011.jpg
# 파일 이동 완료 : Jiri_Novak_0005.jpg
# 파일 이동 완료 : Malik_Mahmud_0001.jpg
# 파일 이동 완료 : Ernie_Eves_0001.jpg
# 파일 이동 완료 : John_Negroponte_0013.jpg
# 파일 이동 완료 : Alex_Sink_0002.jpg
# 파일 이동 완료 : Laura_Bush_0026.jpg
# 파일 이동 완료 : Igor_Ivanov_0013.jpg
# 파일 이동 완료 : James_Young_0001.jpg
# 파일 이동 완료 : Recep_Tayyip_Erdogan_0010.jpg
# 파일 이동 완료 : Janice_Goldfinger_0001.jpg
# 파일 이동 완료 : Jennifer_Capriati_0009.jpg
# 파일 이동 완료 : Jennifer_Aniston_0003.jpg
# 파일 이동 완료 : Barbara_De_Brun_0001.jpg
# 파일 이동 완료 : Daniel_Montgomery_0001.jpg
# 파일 이동 완료 : Carlos_Menem_0005.jpg
# 파일 이동 완료 : Carlos_Ortega_0002.jpg
# 파일 이동 완료 : Mohammad_Khatami_0003.jpg
# 파일 이동 완료 : Steve_Stirling_0001.jpg
# 파일 이동 완료 : William_Ford_Jr_0006.jpg
# 파일 이동 완료 : Richard_Myers_0004.jpg
# 파일 이동 완료 : Dick_Vermeil_0001.jpg
# 파일 이동 완료 : Tony_Blair_0010.jpg
# 파일 이동 완료 : Tony_Blair_0023.jpg
# 파일 이동 완료 : Tom_Daschle_0011.jpg
# 파일 이동 완료 : Naomi_Watts_0009.jpg
# 파일 이동 완료 : David_Howard_0001.jpg
# 파일 이동 완료 : Stefano_Basalini_0001.jpg
# 파일 이동 완료 : Donald_Rumsfeld_0088.jpg
# 파일 이동 완료 : Sok_An_0001.jpg
# 파일 이동 완료 : Roy_Moore_0001.jpg
# 파일 이동 완료 : Edward_James_Olmos_0001.jpg
# 파일 이동 완료 : Nino_DAngelo_0001.jpg
# 파일 이동 완료 : Mark_Wahlberg_0001.jpg
# 파일 이동 완료 : Jeremy_Fogel_0001.jpg
# 파일 이동 완료 : Lorne_Michaels_0001.jpg
# 파일 이동 완료 : Jackie_Chan_0007.jpg
# 파일 이동 완료 : Gus_Frerotte_0001.jpg
# 파일 이동 완료 : Laura_Bush_0023.jpg
# 파일 이동 완료 : Steven_Spielberg_0007.jpg
# 파일 이동 완료 : Bob_Crippen_0001.jpg
# 파일 이동 완료 : Mike_Babcock_0002.jpg
# 파일 이동 완료 : Namuddu_Florence_0001.jpg
# 파일 이동 완료 : Terry_Stotts_0001.jpg
# 파일 이동 완료 : Colin_Powell_0121.jpg
# 파일 이동 완료 : Erwin_Abdullah_0001.jpg
# 파일 이동 완료 : Eric_Robert_Rudolph_0001.jpg
# 파일 이동 완료 : Jacques_Chirac_0014.jpg
# 파일 이동 완료 : Valdas_Adamkus_0002.jpg
# 파일 이동 완료 : George_Robertson_0013.jpg
# 파일 이동 완료 : Larry_Ellison_0001.jpg
# 파일 이동 완료 : Tung_Chee-hwa_0005.jpg
# 파일 이동 완료 : Donald_Rumsfeld_0113.jpg
# 파일 이동 완료 : James_Blake_0013.jpg
# 파일 이동 완료 : Margaret_Thatcher_0001.jpg
# 파일 이동 완료 : Julianna_Margulies_0001.jpg
# 파일 이동 완료 : George_W_Bush_0170.jpg
# 파일 이동 완료 : Gloria_Trevi_0004.jpg
# 파일 이동 완료 : Michael_Lechner_0001.jpg
# 파일 이동 완료 : Kate_Hudson_0007.jpg
# 파일 이동 완료 : Eve_Ensler_0001.jpg
# 파일 이동 완료 : Li_Zhaoxing_0007.jpg
# 파일 이동 완료 : Jean_Chretien_0046.jpg
# 파일 이동 완료 : Binyamin_Ben-Eliezer_0005.jpg
# 파일 이동 완료 : Emily_Stevens_0001.jpg
# 파일 이동 완료 : Paradorn_Srichaphan_0006.jpg
# 파일 이동 완료 : Tony_Blair_0124.jpg
# 파일 이동 완료 : Bill_McBride_0009.jpg
# 파일 이동 완료 : Gerry_Parsky_0001.jpg
# 파일 이동 완료 : Gonzalo_Sanchez_de_Lozada_0001.jpg
# 파일 이동 완료 : Francisco_Maturana_0001.jpg
# 파일 이동 완료 : Pervez_Musharraf_0002.jpg
# 파일 이동 완료 : Colin_Powell_0213.jpg
# 파일 이동 완료 : Queen_Elizabeth_II_0011.jpg
# 파일 이동 완료 : Mitchell_Potter_0001.jpg
# 파일 이동 완료 : Ben_Curtis_0003.jpg
# 파일 이동 완료 : Leo_Mullin_0001.jpg
# 파일 이동 완료 : Richard_Carl_0001.jpg
# 파일 이동 완료 : Tian_Liang_0001.jpg
# 파일 이동 완료 : Leonard_Hamilton_0001.jpg
# 파일 이동 완료 : George_W_Bush_0205.jpg
# 파일 이동 완료 : Choi_Sung-hong_0001.jpg
# 파일 이동 완료 : JJ_Redick_0002.jpg
# 파일 이동 완료 : Hassanal_Bolkiah_0001.jpg
# 파일 이동 완료 : Edward_Greenspan_0001.jpg
# 파일 이동 완료 : Veronica_Lake_0001.jpg
# 파일 이동 완료 : Spencer_Abraham_0011.jpg
# 파일 이동 완료 : Prince_Naruhito_0001.jpg
# 파일 이동 완료 : Raoul_Ruiz_0002.jpg
# 파일 이동 완료 : Colin_Powell_0224.jpg
# 파일 이동 완료 : Junichiro_Koizumi_0011.jpg
# 파일 이동 완료 : Joe_Mantegna_0001.jpg
# 파일 이동 완료 : George_W_Bush_0250.jpg
# 파일 이동 완료 : Boris_Yeltsin_0001.jpg
# 파일 이동 완료 : Diana_Silvius_0001.jpg
# 파일 이동 완료 : Atal_Bihari_Vajpayee_0011.jpg
# 파일 이동 완료 : George_W_Bush_0403.jpg
# 파일 이동 완료 : Bernard_Law_0003.jpg
# 파일 이동 완료 : Oscar_Elias_Biscet_0001.jpg
# 파일 이동 완료 : Sergio_Vieira_De_Mello_0005.jpg
# 파일 이동 완료 : Diana_Taylor_0001.jpg
# 파일 이동 완료 : Jean_Todt_0001.jpg
# 파일 이동 완료 : Elvis_Presley_0002.jpg
# 파일 이동 완료 : Pupi_Avati_0004.jpg
# 파일 이동 완료 : Michael_Schumacher_0005.jpg
# 파일 이동 완료 : Mathilda_Karel_Spak_0001.jpg
# 파일 이동 완료 : Gala_Leon_Garcia_0001.jpg
# 파일 이동 완료 : Rod_Thorn_0001.jpg
# 파일 이동 완료 : Catherine_Zeta-Jones_0005.jpg
# 파일 이동 완료 : Zhu_Rongji_0002.jpg
# 파일 이동 완료 : Jim_Spinoza_0001.jpg
# 파일 이동 완료 : Michael_Jackson_0009.jpg
# 파일 이동 완료 : Joe_Mantello_0001.jpg
# 파일 이동 완료 : Princess_Aiko_0001.jpg
# ...
# 파일 이동 완료 : Jack_Straw_0019.jpg
# 파일 이동 완료 : Sergio_Vieira_De_Mello_0006.jpg
# 파일 이동 완료 : George_W_Bush_0328.jpg
# 파일 이동 완료 : Bridget_Fonda_0002.jpg
# 파일 이동 완료 : Cho_Myung-kyun_0001.jpg
# 파일 이동 완료 : Roh_Moo-hyun_0010.jpg
# 파일 이동 완료 : Joseph_Galante_0001.jpg
# 파일 이동 완료 : Brad_Johnson_0005.jpg
# 파일 이동 완료 : Agnes_Bruckner_0001.jpg
# 파일 이동 완료 : Colin_Powell_0115.jpg
# 파일 이동 완료 : George_W_Bush_0518.jpg
# 파일 이동 완료 : Tariq_Aziz_0002.jpg
# 파일 이동 완료 : Fujio_Cho_0005.jpg
# 파일 이동 완료 : Hal_Gehman_0005.jpg
# 파일 이동 완료 : Irina_Framtsova_0001.jpg
# 파일 이동 완료 : Costas_Simitis_0003.jpg
# 파일 이동 완료 : Hedayat_Amin_Arsala_0001.jpg
# 파일 이동 완료 : Marcelo_Rios_0005.jpg
# 파일 이동 완료 : John_Connolly_0001.jpg
# 파일 이동 완료 : Rick_Bragg_0001.jpg
# 파일 이동 완료 : Jose_Viegas_Filho_0002.jpg
# 파일 이동 완료 : Hamid_Karzai_0012.jpg
# 파일 이동 완료 : Lynne_Cheney_0002.jpg
# 파일 이동 완료 : George_W_Bush_0061.jpg
# 파일 이동 완료 : Charlton_Heston_0004.jpg
# 파일 이동 완료 : Colin_Powell_0069.jpg
# 파일 이동 완료 : George_W_Bush_0091.jpg
# 파일 이동 완료 : Gerhard_Schroeder_0013.jpg
# 파일 이동 완료 : Albert_Costa_0006.jpg
# 파일 이동 완료 : Leonid_Kuchma_0004.jpg
# 파일 이동 완료 : Harry_Schmidt_0001.jpg
# 파일 이동 완료 : Paul_Lo_Duca_0001.jpg
# 파일 이동 완료 : Hugo_Chavez_0025.jpg
# 파일 이동 완료 : Liliana_Cavani_0001.jpg
# 파일 이동 완료 : William_Webster_0001.jpg
# 파일 이동 완료 : Chuck_Finley_0001.jpg
# 파일 이동 완료 : John_Timoney_0002.jpg
# 파일 이동 완료 : David_Beckham_0029.jpg
# 파일 이동 완료 : George_W_Bush_0324.jpg
# 파일 이동 완료 : Billy_Sollie_0001.jpg
# 파일 이동 완료 : William_Hochul_0001.jpg
# 파일 이동 완료 : Roger_Toussaint_0001.jpg
# 파일 이동 완료 : Kofi_Annan_0002.jpg
# 파일 이동 완료 : Nancy_Powell_0001.jpg
# 파일 이동 완료 : Nestor_Kirchner_0027.jpg
# 파일 이동 완료 : Tom_Ridge_0017.jpg
# 파일 이동 완료 : Recep_Tayyip_Erdogan_0007.jpg
# 파일 이동 완료 : John_Warner_0004.jpg
# 파일 이동 완료 : Maria_Simon_0001.jpg
# 파일 이동 완료 : Liu_Ye_0001.jpg
# 파일 이동 완료 : Edward_Lu_0005.jpg
# 파일 이동 완료 : Juan_Pablo_Montoya_0005.jpg
# 파일 이동 완료 : Pete_Aldridge_0001.jpg
# 파일 이동 완료 : Harbhajan_Singh_0002.jpg
# 파일 이동 완료 : Cindy_Crawford_0001.jpg
# 파일 이동 완료 : Mona_Locke_0001.jpg
# 파일 이동 완료 : George_W_Bush_0504.jpg
# 파일 이동 완료 : Pierce_Brosnan_0009.jpg
# 파일 이동 완료 : Jennifer_Capriati_0019.jpg
# 파일 이동 완료 : Jack_Straw_0001.jpg
# 파일 이동 완료 : Michael_Boyce_0001.jpg
# 파일 이동 완료 : Tony_Blair_0071.jpg
# 파일 이동 완료 : Carlos_Manuel_Pruneda_0003.jpg
# 파일 이동 완료 : Reggie_Miller_0002.jpg
# 파일 이동 완료 : Nicolas_Lapentti_0001.jpg
# 파일 이동 완료 : Pierre_Gagnon_0001.jpg
# 파일 이동 완료 : Jacques_Chirac_0005.jpg
# 파일 이동 완료 : Alan_Ball_0001.jpg
# 파일 이동 완료 : George_W_Bush_0241.jpg
# 파일 이동 완료 : George_W_Bush_0209.jpg
# 파일 이동 완료 : George_Ryan_0004.jpg
# 파일 이동 완료 : Vladimir_Putin_0030.jpg
# 파일 이동 완료 : Ben_Cahoon_0001.jpg
# 파일 이동 완료 : Thomas_OBrien_0006.jpg
# 파일 이동 완료 : Heinrich_Wolfgang_0001.jpg
# 파일 이동 완료 : Tamara_Mowry_0001.jpg
# 파일 이동 완료 : Andre_Agassi_0023.jpg
# 파일 이동 완료 : Tim_Henman_0003.jpg
# 파일 이동 완료 : Leandro_Andrade_0001.jpg
# 파일 이동 완료 : George_W_Bush_0204.jpg
# 파일 이동 완료 : Ruano_Pascual_0001.jpg
# 파일 이동 완료 : Bob_Colvin_0001.jpg
# 파일 이동 완료 : Juliette_Lewis_0001.jpg
# 파일 이동 완료 : Jose_Miguel_Aleman_0001.jpg
# 파일 이동 완료 : Jennifer_Capriati_0024.jpg
# 파일 이동 완료 : Lleyton_Hewitt_0032.jpg
# 파일 이동 완료 : Jeannette_Biedermann_0001.jpg
# 파일 이동 완료 : Michael_Ballack_0002.jpg
# 파일 이동 완료 : Patty_Schnyder_0003.jpg
# 파일 이동 완료 : Patrik_Kristiansson_0001.jpg
# 파일 이동 완료 : Leonid_Kuchma_0005.jpg
# 파일 이동 완료 : Albrecht_Mentz_0002.jpg
# 파일 이동 완료 : Donna_Barrera_0001.jpg
# 파일 이동 완료 : William_Ford_Jr_0002.jpg
# 파일 이동 완료 : Diana_Munz_0002.jpg
# 파일 이동 완료 : Huan_Chung_Yi_0001.jpg
# 파일 이동 완료 : Zhu_Rongji_0008.jpg
# 파일 이동 완료 : Colin_Campbell_0001.jpg
# 파일 이동 완료 : Manfred_Reyes_Villa_0001.jpg
# 파일 이동 완료 : Joschka_Fischer_0010.jpg
# 파일 이동 완료 : Tom_Curley_0001.jpg
# 파일 이동 완료 : Mario_Alfaro-Lopez_0001.jpg
# 파일 이동 완료 : Andrei_Konchalovsky_0001.jpg
# 파일 이동 완료 : Johnny_Benson_0001.jpg
# 파일 이동 완료 : George_W_Bush_0173.jpg
# 파일 이동 완료 : Jacques_Chirac_0036.jpg
# 파일 이동 완료 : Ricardo_Lagos_0009.jpg
# 파일 이동 완료 : George_W_Bush_0132.jpg
# 파일 이동 완료 : Ken_Watanabe_0002.jpg
# 파일 이동 완료 : Jean_Chretien_0039.jpg
# 파일 이동 완료 : George_W_Bush_0152.jpg
# 파일 이동 완료 : Janet_Ecker_0001.jpg
# 파일 이동 완료 : Leandrinho_Barbosa_0001.jpg
# 파일 이동 완료 : Arnold_Schwarzenegger_0014.jpg
# 파일 이동 완료 : Jennifer_Lopez_0001.jpg
# 파일 이동 완료 : Paul_Bremer_0015.jpg
# 파일 이동 완료 : Gordon_Brown_0004.jpg
# 파일 이동 완료 : Tang_Jiaxuan_0002.jpg
# 파일 이동 완료 : Dominique_de_Villepin_0015.jpg
# 파일 이동 완료 : Bill_Clinton_0026.jpg
# 파일 이동 완료 : Kamal_Kharrazi_0006.jpg
# 파일 이동 완료 : Lily_Tomlin_0001.jpg
# 파일 이동 완료 : Bill_Pryor_0001.jpg
# 파일 이동 완료 : Donald_Rumsfeld_0002.jpg
# 파일 이동 완료 : Steve_Allan_0001.jpg
# 파일 이동 완료 : George_W_Bush_0073.jpg
# 파일 이동 완료 : Mikulas_Dzurinda_0002.jpg
# 파일 이동 완료 : Mohammed_Baqir_al-Hakim_0002.jpg
# 파일 이동 완료 : Anna_Jones_0001.jpg
# 파일 이동 완료 : Kevin_Costner_0007.jpg
# 파일 이동 완료 : Ian_Moran_0001.jpg
# 파일 이동 완료 : Geraldine_Chaplin_0001.jpg
# 파일 이동 완료 : Brian_Florence_0001.jpg
# 파일 이동 완료 : Doris_Roberts_0002.jpg
# 파일 이동 완료 : Jim_Paxson_0001.jpg
# 파일 이동 완료 : Tom_Scully_0001.jpg
# 파일 이동 완료 : Gordon_Campbell_0001.jpg
# 파일 이동 완료 : Elizabeth_Dole_0003.jpg
# 파일 이동 완료 : Kenneth_Evans_0002.jpg
# 파일 이동 완료 : Simon_Chalk_0001.jpg
# 파일 이동 완료 : Bill_Mauldin_0001.jpg
# 파일 이동 완료 : Vaclav_Havel_0002.jpg
# 파일 이동 완료 : John_Reid_0003.jpg
# 파일 이동 완료 : Yasser_Arafat_0004.jpg
# 파일 이동 완료 : Riek_Blanjaar_0001.jpg
# 파일 이동 완료 : Frank_Griswold_0002.jpg
# 파일 이동 완료 : Jennifer_Capriati_0040.jpg
# 파일 이동 완료 : Mikhail_Gorbachev_0001.jpg
# 파일 이동 완료 : Sean_Penn_0001.jpg
# 파일 이동 완료 : John_Taylor_0002.jpg
# 파일 이동 완료 : Yoko_Ono_0004.jpg
# 파일 이동 완료 : Johnny_Tapia_0002.jpg
# 파일 이동 완료 : Thomas_Ulrich_0001.jpg
# 파일 이동 완료 : Steve_McManaman_0001.jpg
# 파일 이동 완료 : Naomi_Watts_0004.jpg
# 파일 이동 완료 : Oracene_Williams_0001.jpg
# 파일 이동 완료 : Flavia_Delaroli_0002.jpg
# 파일 이동 완료 : Gregorio_Honasan_0001.jpg
# 파일 이동 완료 : Alex_Penelas_0002.jpg
# 파일 이동 완료 : Colin_Powell_0010.jpg
# 파일 이동 완료 : Freddy_Garcia_0001.jpg
# 파일 이동 완료 : Hank_Stram_0001.jpg
# 파일 이동 완료 : Bill_Graham_0006.jpg
# 파일 이동 완료 : Alberta_Lee_0001.jpg
# 파일 이동 완료 : Eileen_Coparropa_0002.jpg
# 파일 이동 완료 : Clara_Harris_0003.jpg
# 파일 이동 완료 : Liza_Minnelli_0006.jpg
# 파일 이동 완료 : Perri_Shaw_0001.jpg
# 파일 이동 완료 : Rod_Stewart_0001.jpg
# 파일 이동 완료 : Matthew_Perry_0002.jpg
# 파일 이동 완료 : Brian_Gregory_0001.jpg
# 파일 이동 완료 : Jeremy_Greenstock_0005.jpg
# 파일 이동 완료 : Monica_Bellucci_0002.jpg
# 파일 이동 완료 : Marc_Grossman_0002.jpg
# 파일 이동 완료 : Dominic_Monaghan_0001.jpg
# 파일 이동 완료 : Kent_Rominger_0002.jpg
# 파일 이동 완료 : Rogelio_Ramos_0001.jpg
# 파일 이동 완료 : Carlos_Menem_0015.jpg
# 파일 이동 완료 : Ariel_Sharon_0060.jpg
# 파일 이동 완료 : Mukesh_Ambani_0001.jpg
# 파일 이동 완료 : Tom_Daschle_0019.jpg
# 파일 이동 완료 : Jim_Doyle_0001.jpg
# 파일 이동 완료 : Richard_Virenque_0003.jpg
# 파일 이동 완료 : John_Paul_II_0010.jpg
# 파일 이동 완료 : Odilia_Collazo_0001.jpg
# 파일 이동 완료 : Benazir_Bhutto_0001.jpg
# 파일 이동 완료 : Guillermo_Coria_0028.jpg
# 파일 이동 완료 : Wolfgang_Schuessel_0004.jpg
# 파일 이동 완료 : Bill_Frist_0005.jpg
# 파일 이동 완료 : Tomomi_Morita_0001.jpg
# 파일 이동 완료 : Joan_Laporta_0009.jpg
# 파일 이동 완료 : Juan_Pablo_Montoya_0007.jpg
# 파일 이동 완료 : Patrick_Roy_0002.jpg
# 파일 이동 완료 : Peter_Hillary_0002.jpg
# 파일 이동 완료 : Keizo_Yamada_0001.jpg
# 파일 이동 완료 : Bill_Simon_0003.jpg
# 파일 이동 완료 : Leslie_Ann_Woodward_0002.jpg
# 파일 이동 완료 : George_Robertson_0019.jpg
# 파일 이동 완료 : Hugo_Chavez_0057.jpg
# 파일 이동 완료 : Andy_Warhol_0001.jpg
# 파일 이동 완료 : George_W_Bush_0268.jpg
# 파일 이동 완료 : Sheryl_Crow_0003.jpg
# 파일 이동 완료 : Mary_Steenburgen_0002.jpg
# 파일 이동 완료 : Angelina_Jolie_0005.jpg
# 파일 이동 완료 : Hamid_Karzai_0001.jpg
# 파일 이동 완료 : Vojislav_Kostunica_0003.jpg
# 파일 이동 완료 : Michael_Jackson_0002.jpg
# 파일 이동 완료 : Monique_Garbrecht-Enfeldt_0002.jpg
# 파일 이동 완료 : Jiang_Zemin_0016.jpg
# 파일 이동 완료 : Rustu_Recber_0001.jpg
# 파일 이동 완료 : Mary_Carey_0003.jpg
# 파일 이동 완료 : Keith_Lowen_0001.jpg
# 파일 이동 완료 : Mike_Weir_0005.jpg
# 파일 이동 완료 : Ulrich_Kueperkoch_0001.jpg
# 파일 이동 완료 : Kareena_Kapoor_0001.jpg
# 파일 이동 완료 : Javier_Solana_0007.jpg
# 파일 이동 완료 : Frances_Fisher_0001.jpg
# 파일 이동 완료 : Clay_Aiken_0004.jpg
# 파일 이동 완료 : Cristina_Kirchner_0001.jpg
# 파일 이동 완료 : Gary_Forsee_0001.jpg
# 파일 이동 완료 : Diane_Ladd_0001.jpg
# 파일 이동 완료 : Brian_Mulroney_0001.jpg
# 파일 이동 완료 : Rudolph_Giuliani_0010.jpg
# 파일 이동 완료 : George_W_Bush_0172.jpg
# 파일 이동 완료 : Jim_Wessling_0001.jpg
# 파일 이동 완료 : Jonathan_Fine_0001.jpg
# 파일 이동 완료 : Fred_Thompson_0001.jpg
# 파일 이동 완료 : Angelo_Reyes_0001.jpg
# 파일 이동 완료 : Gary_Coleman_0001.jpg
# 파일 이동 완료 : Rainer_Schuettler_0004.jpg
# 파일 이동 완료 : Asif_Ali_Zardari_0001.jpg
# 파일 이동 완료 : Jay_Garner_0003.jpg
# 파일 이동 완료 : Bernardo_Segura_0001.jpg
# 파일 이동 완료 : Christian_Malcolm_0001.jpg
# 파일 이동 완료 : Scott_Wolf_0001.jpg
# 파일 이동 완료 : Bill_Paxton_0002.jpg
# 파일 이동 완료 : Andreas_Vinciguerra_0001.jpg
# 파일 이동 완료 : Serena_Williams_0048.jpg
# 파일 이동 완료 : Shannon_OBrien_0002.jpg
# 파일 이동 완료 : Gerhard_Schroeder_0023.jpg
# 파일 이동 완료 : Steffi_Graf_0003.jpg
# 파일 이동 완료 : Thomas_OBrien_0005.jpg
# 파일 이동 완료 : Toshihiko_Fukui_0001.jpg
# 파일 이동 완료 : Gerhard_Schroeder_0044.jpg
# 파일 이동 완료 : Donald_Rumsfeld_0073.jpg
# 파일 이동 완료 : Mary_Frances_Seiter_0001.jpg
# 파일 이동 완료 : Rudolph_Giuliani_0014.jpg
# 파일 이동 완료 : Hal_Sellers_0001.jpg
# 파일 이동 완료 : Radovan_Karadzic_0001.jpg
# 파일 이동 완료 : Laila_Ali_0002.jpg
# 파일 이동 완료 : Mohammad_Aktar_0001.jpg
# 파일 이동 완료 : Tom_Ridge_0024.jpg
# 파일 이동 완료 : Jamie_King_0001.jpg
# 파일 이동 완료 : Herta_Daeubler-Gmelin_0002.jpg
# 파일 이동 완료 : Jacques_Chirac_0016.jpg
# 파일 이동 완료 : Tom_Cruise_0004.jpg
# 파일 이동 완료 : Andrew_Shutley_0001.jpg
# 파일 이동 완료 : Ellen_MacArthur_0001.jpg
# 파일 이동 완료 : Vijay_Nambiar_0001.jpg
# 파일 이동 완료 : John_Howard_0012.jpg
# 파일 이동 완료 : Frank_Schmoekel_0001.jpg
# 파일 이동 완료 : Julianne_Moore_0018.jpg
# 파일 이동 완료 : Gerhard_Schroeder_0107.jpg
# 파일 이동 완료 : Joshua_Harapko_0001.jpg
# 파일 이동 완료 : William_Nessen_0001.jpg
# 파일 이동 완료 : Recep_Tayyip_Erdogan_0025.jpg
# 파일 이동 완료 : Rainer_Schuettler_0001.jpg
# 파일 이동 완료 : Katherine_Harris_0002.jpg
# 파일 이동 완료 : Colleen_Donovan_0001.jpg
# 파일 이동 완료 : John_Warner_0002.jpg
# 파일 이동 완료 : Jennifer_Garner_0010.jpg
# 파일 이동 완료 : Richard_Harris_0001.jpg
# 파일 이동 완료 : Peter_Arnett_0002.jpg
# 파일 이동 완료 : Todd_Haynes_0003.jpg
# 파일 이동 완료 : Princess_Aiko_0002.jpg
# 파일 이동 완료 : George_W_Bush_0094.jpg
# 파일 이동 완료 : Megawati_Sukarnoputri_0031.jpg
# 파일 이동 완료 : John_McKay_0001.jpg
# 파일 이동 완료 : Laura_Bush_0029.jpg
# 파일 이동 완료 : Tom_Harkin_0001.jpg
# 파일 이동 완료 : Silvio_Berlusconi_0001.jpg
# 파일 이동 완료 : Michael_Bloomberg_0007.jpg
# 파일 이동 완료 : Laszlo_Kovacs_0001.jpg
# 파일 이동 완료 : Steve_Waugh_0001.jpg
# 파일 이동 완료 : Tony_Blair_0006.jpg
# 파일 이동 완료 : Jacques_Chirac_0041.jpg
# 파일 이동 완료 : Thabo_Mbeki_0005.jpg
# 파일 이동 완료 : Nicanor_Duarte_Frutos_0002.jpg
# 파일 이동 완료 : Adrian_Nastase_0002.jpg
# 파일 이동 완료 : Colin_Powell_0123.jpg
# 파일 이동 완료 : Carlo_Ancelotti_0003.jpg
# 파일 이동 완료 : George_Clooney_0004.jpg
# 파일 이동 완료 : Robin_McLaurin_Williams_0002.jpg
# 파일 이동 완료 : Renee_Zellweger_0007.jpg
# 파일 이동 완료 : Darrell_Porter_0002.jpg
# 파일 이동 완료 : Lesia_Burlak_0001.jpg
# 파일 이동 완료 : Kim_Clijsters_0001.jpg
# 파일 이동 완료 : Joseph_Lopez_0001.jpg
# 파일 이동 완료 : Richard_Myers_0007.jpg
# 파일 이동 완료 : Gerhard_Schroeder_0089.jpg
# 파일 이동 완료 : Yasushi_Chimura_0001.jpg
# 파일 이동 완료 : John_Thune_0001.jpg
# 파일 이동 완료 : Rob_Marshall_0002.jpg
# 파일 이동 완료 : Paris_Hilton_0002.jpg
# 파일 이동 완료 : Michael_Phelps_0003.jpg
# 파일 이동 완료 : Marta_Dominguz_0001.jpg
# 파일 이동 완료 : George_Robertson_0002.jpg
# 파일 이동 완료 : Tubby_Smith_0001.jpg
# 파일 이동 완료 : Yasar_Yakis_0004.jpg
# 파일 이동 완료 : Arnoldo_Aleman_0003.jpg
# 파일 이동 완료 : Junichiro_Koizumi_0060.jpg
# 파일 이동 완료 : Stephen_Ambrose_0001.jpg
# 파일 이동 완료 : Inocencio_Arias_0002.jpg
# 파일 이동 완료 : Thomas_Malchow_0001.jpg
# 파일 이동 완료 : Martha_Stewart_0003.jpg
# 파일 이동 완료 : Gerhard_Schroeder_0078.jpg
# 파일 이동 완료 : Carol_Niedermayer_0001.jpg
# 파일 이동 완료 : Jose_Maria_Aznar_0018.jpg
# 파일 이동 완료 : Donald_Regan_0001.jpg
# 파일 이동 완료 : Ariel_Sharon_0024.jpg
# 파일 이동 완료 : Maria_Shriver_0002.jpg
# 파일 이동 완료 : Tommy_Haas_0005.jpg
# 파일 이동 완료 : Hans_Blix_0026.jpg
# 파일 이동 완료 : Ignatius_Wang_0001.jpg
# 파일 이동 완료 : Juan_Carlos_Ferrero_0025.jpg
# 파일 이동 완료 : Salma_Hayek_0013.jpg
# 파일 이동 완료 : Patsy_Hardy_0001.jpg
# 파일 이동 완료 : Sheryl_Crow_0002.jpg
# 파일 이동 완료 : John_Ashcroft_0035.jpg
# 파일 이동 완료 : Duane_Lee_Chapman_0002.jpg
# 파일 이동 완료 : Bernard_Landry_0003.jpg
# 파일 이동 완료 : Gianna_Angelopoulos-Daskalaki_0003.jpg
# 파일 이동 완료 : Ray_Allen_0002.jpg
# 파일 이동 완료 : Alec_Baldwin_0003.jpg
# 파일 이동 완료 : Phillip_Fulmer_0001.jpg
# 파일 이동 완료 : Carlos_Iturgaitz_0001.jpg
# 파일 이동 완료 : Clara_Harris_0001.jpg
# 파일 이동 완료 : Jessica_Capshaw_0001.jpg
# 파일 이동 완료 : Jon_Corzine_0001.jpg
# 파일 이동 완료 : Roger_Moore_0005.jpg
# 파일 이동 완료 : Gerhard_Schroeder_0099.jpg
# 파일 이동 완료 : Ana_Palacio_0007.jpg
# 파일 이동 완료 : Mark_Salter_0001.jpg
# 파일 이동 완료 : Lleyton_Hewitt_0031.jpg
# 파일 이동 완료 : Hermann_Maier_0002.jpg
# 파일 이동 완료 : Marcelo_Rios_0004.jpg
# 파일 이동 완료 : Benjamin_McKenzie_0001.jpg
# 파일 이동 완료 : George_W_Bush_0359.jpg
# 파일 이동 완료 : Naji_Sabri_0001.jpg
# 파일 이동 완료 : Jacques_Chirac_0028.jpg
# 파일 이동 완료 : Richard_Myers_0014.jpg
# 파일 이동 완료 : Mireya_Moscoso_0001.jpg
# 파일 이동 완료 : Mike_Krzyzewski_0002.jpg
# 파일 이동 완료 : Serena_Williams_0045.jpg
# 파일 이동 완료 : Winona_Ryder_0013.jpg
# 파일 이동 완료 : Terence_Newman_0001.jpg
# 파일 이동 완료 : Tony_Blair_0131.jpg
# 파일 이동 완료 : Gray_Davis_0023.jpg
# 파일 이동 완료 : Jean-Marc_de_La_Sabliere_0002.jpg
# 파일 이동 완료 : Martha_Lucia_Ramirez_0002.jpg
# 파일 이동 완료 : Jack_Straw_0020.jpg
# 파일 이동 완료 : Emmanuel_Filiberto_0001.jpg
# 파일 이동 완료 : Sebastien_Grosjean_0002.jpg
# 파일 이동 완료 : Bill_Sizemore_0001.jpg
# 파일 이동 완료 : Kate_Winslet_0003.jpg
# 파일 이동 완료 : Lenny_Wilkens_0002.jpg
# 파일 이동 완료 : Prince_William_0001.jpg
# 파일 이동 완료 : Junichiro_Koizumi_0005.jpg
# 파일 이동 완료 : Isidro_Pastor_0001.jpg
# 파일 이동 완료 : Michael_Jackson_0006.jpg
# 파일 이동 완료 : Tony_Blair_0046.jpg
# 파일 이동 완료 : George_W_Bush_0099.jpg
# 파일 이동 완료 : David_Nalbandian_0014.jpg
# 파일 이동 완료 : Jennifer_Garner_0007.jpg
# 파일 이동 완료 : Michael_Kahn_0001.jpg
# 파일 이동 완료 : Gerhard_Schroeder_0104.jpg
# 파일 이동 완료 : Javier_Bardem_0001.jpg
# 파일 이동 완료 : Daryl_Sabara_0001.jpg
# 파일 이동 완료 : George_W_Bush_0515.jpg
# 파일 이동 완료 : Roh_Moo-hyun_0007.jpg
# 파일 이동 완료 : Bernard_Law_0004.jpg
# 파일 이동 완료 : Bob_Herz_0001.jpg
# 파일 이동 완료 : Jean_Chretien_0036.jpg
# 파일 이동 완료 : Charles_Moose_0013.jpg
# 파일 이동 완료 : Javier_Weber_0002.jpg
# 파일 이동 완료 : Jason_Bentley_0001.jpg
# 파일 이동 완료 : David_Coulthard_0002.jpg
# 파일 이동 완료 : Pascal_Lamy_0001.jpg
# 파일 이동 완료 : Brian_Clemens_0001.jpg
# 파일 이동 완료 : Hugh_Carey_0001.jpg
# 파일 이동 완료 : Mike_Flanagan_0001.jpg
# 파일 이동 완료 : Vladimir_Putin_0043.jpg
# 파일 이동 완료 : Doris_Schroeder_0002.jpg
# 파일 이동 완료 : Kenneth_Cooper_0001.jpg
# 파일 이동 완료 : Ashanti_0004.jpg
# 파일 이동 완료 : Jesse_Ventura_0001.jpg
# 파일 이동 완료 : Win_Aung_0002.jpg
# 파일 이동 완료 : Mike_Szymanczyk_0001.jpg
# 파일 이동 완료 : Harry_Schmidt_0003.jpg
# 파일 이동 완료 : Tonino_Guerra_0001.jpg
# 파일 이동 완료 : Astrid_Betancourt_0001.jpg
# 파일 이동 완료 : Richard_Gere_0003.jpg
# 파일 이동 완료 : Laura_Bush_0019.jpg
# 파일 이동 완료 : Howard_Dean_0011.jpg
# 파일 이동 완료 : Jose_Maria_Aznar_0014.jpg
# 파일 이동 완료 : Geraldo_Rivera_0001.jpg
# 파일 이동 완료 : David_Caraway_0002.jpg
# 파일 이동 완료 : Isabella_Rossellini_0002.jpg
# 파일 이동 완료 : James_Brosnahan_0001.jpg
# 파일 이동 완료 : Donald_Rumsfeld_0014.jpg
# 파일 이동 완료 : Michelle_Lecky_0001.jpg
# 파일 이동 완료 : Junichiro_Koizumi_0059.jpg
# 파일 이동 완료 : Cameron_Diaz_0001.jpg
# 파일 이동 완료 : Vladimir_Putin_0006.jpg
# 파일 이동 완료 : David_Wells_0003.jpg
# 파일 이동 완료 : Junichiro_Koizumi_0057.jpg
# 파일 이동 완료 : Ann_Morgan_0001.jpg
# 파일 이동 완료 : George_W_Bush_0294.jpg
# 파일 이동 완료 : David_Beckham_0006.jpg
# 파일 이동 완료 : James_Traficant_0003.jpg
# 파일 이동 완료 : Ed_Sullivan_0001.jpg
# 파일 이동 완료 : Magda_Kertasz_0001.jpg
# 파일 이동 완료 : Alan_Greenspan_0004.jpg
# 파일 이동 완료 : Dolma_Tsering_0002.jpg
# 파일 이동 완료 : Paul_Wellstone_0002.jpg
# 파일 이동 완료 : Jacques_Chirac_0012.jpg
# 파일 이동 완료 : Arnold_Schwarzenegger_0040.jpg
# 파일 이동 완료 : Tang_Jiaxuan_0003.jpg
# 파일 이동 완료 : Luiz_Inacio_Lula_da_Silva_0038.jpg
# 파일 이동 완료 : Brian_StPierre_0001.jpg
# 파일 이동 완료 : Ai_Sugiyama_0005.jpg
# 파일 이동 완료 : Al_Sharpton_0004.jpg
# 파일 이동 완료 : Lucy_Liu_0001.jpg
# 파일 이동 완료 : Ariel_Sharon_0012.jpg
# 파일 이동 완료 : Brian_Mulroney_0002.jpg
# 파일 이동 완료 : Javier_Solana_0003.jpg
# 파일 이동 완료 : Marc_Gold_0001.jpg
# 파일 이동 완료 : Anthony_Mazur_0001.jpg
# 파일 이동 완료 : Gil_de_Ferran_0003.jpg
# 파일 이동 완료 : Ronaldo_Luis_Nazario_de_Lima_0001.jpg
# 파일 이동 완료 : Bill_Clinton_0008.jpg
# 파일 이동 완료 : Arnie_Boehm_0001.jpg
# 파일 이동 완료 : Jason_Kidd_0007.jpg
# 파일 이동 완료 : Martin_Verkerk_0002.jpg
# 파일 이동 완료 : Sami_Al-Arian_0001.jpg
# 파일 이동 완료 : Richard_Myers_0017.jpg
# 파일 이동 완료 : David_Beckham_0030.jpg
# 파일 이동 완료 : Madonna_0001.jpg
# 파일 이동 완료 : Jeremy_Greenstock_0013.jpg
# 파일 이동 완료 : Howard_Dean_0003.jpg
# 파일 이동 완료 : Roger_Machado_0001.jpg
# 파일 이동 완료 : Lea_Fastow_0001.jpg
# 파일 이동 완료 : Tom_Daschle_0004.jpg
# 파일 이동 완료 : George_W_Bush_0334.jpg
# 파일 이동 완료 : Jason_Petty_0001.jpg
# 파일 이동 완료 : Sylvester_Stallone_0005.jpg
# 파일 이동 완료 : Ana_Palacio_0006.jpg
# 파일 이동 완료 : Norah_Jones_0004.jpg
# 파일 이동 완료 : Prince_Claus_0001.jpg
# 파일 이동 완료 : Alastair_Campbell_0002.jpg
# 파일 이동 완료 : Nathan_Powell_0001.jpg
# 파일 이동 완료 : Natalia_Verbeke_0001.jpg
# 파일 이동 완료 : Silvio_Berlusconi_0002.jpg

# %%
## "본인 얼굴"에 대한 파일 리스트의 상위 5개 조회
img_list_my[:5]
# Out:
# ['/content/my_face/my_face_4542.jpg',
#  '/content/my_face/my_face_8245.jpg',
#  '/content/my_face/my_face_2189.jpg',
#  '/content/my_face/my_face_4033.jpg',
#  '/content/my_face/my_face_6878.jpg']

# %%
## 위의 5개 파일이 image_dataset_from_directory에 맞춰 생성한 경로에 알맞게 있는지 확인
## "본인 얼굴"에 대한 파일 리스트를 정렬한 후, 8:2로 나누었기 때문에 위의 상위 5개는 반드시 Training set의 "나의 얼굴" 폴더 안에 있어야 한다.

print(os.path.exists('/content/tr_data/my/my_face_4542.jpg') )
print(os.path.exists('/content/tr_data/my/my_face_8245.jpg') )
print(os.path.exists('/content/tr_data/my/my_face_2189.jpg') )
print(os.path.exists('/content/tr_data/my/my_face_4033.jpg') )
print(os.path.exists('/content/tr_data/my/my_face_6878.jpg') )
# Out:
# True
# True
# True
# True
# True

# %%
print('Training data의 my_face 이미지 수 : ', len(os.listdir('/content/tr_data/my')))
print('Training data의 other_face 이미지 수 : ', len(os.listdir('/content/tr_data/other')))

print('Test data의 my_face 이미지 수 : ', len(os.listdir('/content/te_data/my')))
print('Test data의 other_face 이미지 수 : ', len(os.listdir('/content/te_data/other')))
# Out:
# Training data의 my_face 이미지 수 :  5600
# Training data의 other_face 이미지 수 :  10586
# Test data의 my_face 이미지 수 :  1400
# Test data의 other_face 이미지 수 :  2647

# %% [markdown]
# #### 2) **특정 함수** 사용

# %%
## Training set 데이터 폴더를 데이터셋화
## 이 과정에서 Validation set도 생성
tr_idfd, val_idfd = image_dataset_from_directory(tr_data,                    ## Training 폴더 경로
                                                 class_names=['other','my'], ## 클래스 순서 지정
                                                 batch_size=32,              ## 이미지 덩어리 단위
                                                 image_size=(160,160),       ## 이미지 리사이즈
                                                 shuffle=True,               ## 섞어야 올바르게 분할됨
                                                 seed=2024,                  ## 재현성
                                                 validation_split=0.3,       ## 데이터 스플릿 비율
                                                 subset='both',              ## 데이터셋 나눔 방식
                                                 )
# Out:
# Found 16186 files belonging to 2 classes.
# Using 11331 files for training.
# Using 4855 files for validation.

# %%
## Test set 데이터 폴더를 데이터셋화
te_idfd = image_dataset_from_directory(te_data,                    ## Test 폴더 경로
                                       class_names=['other','my'], ## 클래스 순서 지정
                                       batch_size=32,              ## 이미지 덩어리 단위
                                       image_size=(160,160),       ## 이미지 리사이즈
                                       shuffle=True,               ## 섞어야 올바르게 분할됨
                                       seed=2024                   ## 재현성
                                       )
# Out:
# Found 4047 files belonging to 2 classes.

# %%
## 위에서 만든 이미지 데이터 덩어리가 몇 개인지 확인
len(tr_idfd), len(val_idfd)
# Out:
# (355, 152)

# %% [markdown]
# #### 3) 스케일링

# %%
def rescale(image, label) :
    image = image / 255
    return image, label

# %%
tr_idfd_rescale = tr_idfd.map(rescale)
val_idfd_rescale = val_idfd.map(rescale)
te_idfd_rescale = te_idfd.map(rescale)

# %% [markdown]
# ## 4.미션2

# %% [markdown]
# 데이터셋을 **학습에 적합한 형태**로 만들었다면, **FaceNet 모델로 Transfer Learning**을 수행합니다.
#
# - 1) FaceNet 모델 구조를 생성합니다.
#     - [FaceNet 논문 링크](https://arxiv.org/abs/1503.03832)
#     - FaceNet의 Input은 (160, 160) 사이즈의 이미지입니다.
# - 2) FaceNet 모델 구조 + 구조 추가
#     - FaceNet의 Output은 128차원의 벡터입니다.
#     - 이 과정을 Transfer Learning라고 합니다.

# %% [markdown]
# ### (1) FaceNet 구조 생성

# %% [markdown]
# * **세부 요구사항**
#     - FaceNet의 구조를 생성합니다.
#         - FaceNet 구조 생성에 필요한 함수를 만듭니다.
#     - FaceNet의 구조에 **잘 학습된 가중치**를 부여합니다.
#         - FaceNet 원본 가중치 파일을 공유하였습니다.
#     - (선택사항) FaceNet 모델의 가중치 업데이트를 방지합니다.
#     - 예시 코드에서 사용한 라이브러리
#         - numpy, functools, keras

# %% [markdown]
# #### 1) 모델 구조 생성

# %%
import numpy as np
from functools import partial

import keras
from keras.models import Model

from keras.layers import Input, Dense, Conv2D, MaxPooling2D, Activation
from keras.layers import BatchNormalization, Dropout, GlobalAveragePooling2D
from keras.layers import Lambda, Concatenate, add

from keras import backend as K
from keras.saving import register_keras_serializable

# %%
## 3.6.0.dev2024100303 OK
## 3.6.0 dev2024101103
keras.__version__
# Out:
# '3.7.0.dev2024110706'

# %%
@register_keras_serializable()
def scaling(x, scale):
    return x * scale

@register_keras_serializable()
def conv2d_bn(x,
              filters,
              kernel_size,
              strides=1,
              padding='same',
              activation='relu',
              use_bias=False,
              name=None):
    x = Conv2D(filters,
               kernel_size,
               strides=strides,
               padding=padding,
               use_bias=use_bias,
               name=name)(x)
    if not use_bias:
        bn_axis = 1 if K.image_data_format() == 'channels_first' else 3
        bn_name = _generate_layer_name('BatchNorm', prefix=name)
        x = BatchNormalization(axis=bn_axis, momentum=0.995, epsilon=0.001,
                               scale=False, name=bn_name)(x)
    if activation is not None:
        ac_name = _generate_layer_name('Activation', prefix=name)
        x = Activation(activation, name=ac_name)(x)
    return x

@register_keras_serializable()
def _generate_layer_name(name, branch_idx=None, prefix=None):
    if prefix is None:
        return None
    if branch_idx is None:
        return '_'.join((prefix, name))
    return '_'.join((prefix, 'Branch', str(branch_idx), name))

@register_keras_serializable()
def _inception_resnet_block(x, scale, block_type, block_idx, activation='relu'):
    channel_axis = 1 if K.image_data_format() == 'channels_first' else 3
    if block_idx is None:
        prefix = None
    else:
        prefix = '_'.join((block_type, str(block_idx)))
    name_fmt = partial(_generate_layer_name, prefix=prefix)

    if block_type == 'Block35':
        branch_0 = conv2d_bn(x, 32, 1, name=name_fmt('Conv2d_1x1', 0))
        branch_1 = conv2d_bn(x, 32, 1, name=name_fmt('Conv2d_0a_1x1', 1))
        branch_1 = conv2d_bn(branch_1, 32, 3, name=name_fmt('Conv2d_0b_3x3', 1))
        branch_2 = conv2d_bn(x, 32, 1, name=name_fmt('Conv2d_0a_1x1', 2))
        branch_2 = conv2d_bn(branch_2, 32, 3, name=name_fmt('Conv2d_0b_3x3', 2))
        branch_2 = conv2d_bn(branch_2, 32, 3, name=name_fmt('Conv2d_0c_3x3', 2))
        branches = [branch_0, branch_1, branch_2]
    elif block_type == 'Block17':
        branch_0 = conv2d_bn(x, 128, 1, name=name_fmt('Conv2d_1x1', 0))
        branch_1 = conv2d_bn(x, 128, 1, name=name_fmt('Conv2d_0a_1x1', 1))
        branch_1 = conv2d_bn(branch_1, 128, [1, 7], name=name_fmt('Conv2d_0b_1x7', 1))
        branch_1 = conv2d_bn(branch_1, 128, [7, 1], name=name_fmt('Conv2d_0c_7x1', 1))
        branches = [branch_0, branch_1]
    elif block_type == 'Block8':
        branch_0 = conv2d_bn(x, 192, 1, name=name_fmt('Conv2d_1x1', 0))
        branch_1 = conv2d_bn(x, 192, 1, name=name_fmt('Conv2d_0a_1x1', 1))
        branch_1 = conv2d_bn(branch_1, 192, [1, 3], name=name_fmt('Conv2d_0b_1x3', 1))
        branch_1 = conv2d_bn(branch_1, 192, [3, 1], name=name_fmt('Conv2d_0c_3x1', 1))
        branches = [branch_0, branch_1]
    else:
        raise ValueError('Unknown Inception-ResNet block type. '
                         'Expects "Block35", "Block17" or "Block8", '
                         'but got: ' + str(block_type))

    mixed = Concatenate(axis=channel_axis, name=name_fmt('Concatenate'))(branches)
    up = conv2d_bn(mixed,
                #    K.int_shape(x)[channel_axis],
                   x.shape[channel_axis],
                   1,
                   activation=None,
                   use_bias=True,
                   name=name_fmt('Conv2d_1x1'))
    up = Lambda(scaling,
                # output_shape=K.int_shape(up)[1:],
                output_shape=up.shape[1:],
                arguments={'scale': scale})(up)
    x = add([x, up])
    if activation is not None:
        x = Activation(activation, name=name_fmt('Activation'))(x)
    return x

# %%
@register_keras_serializable()
def InceptionResNetV1(input_shape=(160, 160, 3),
                      classes=128,
                      dropout_keep_prob=0.8,
                      weights_path=None):
    inputs = Input(shape=input_shape)
    x = conv2d_bn(inputs, 32, 3, strides=2, padding='valid', name='Conv2d_1a_3x3')
    x = conv2d_bn(x, 32, 3, padding='valid', name='Conv2d_2a_3x3')
    x = conv2d_bn(x, 64, 3, name='Conv2d_2b_3x3')
    x = MaxPooling2D(3, strides=2, name='MaxPool_3a_3x3')(x)
    x = conv2d_bn(x, 80, 1, padding='valid', name='Conv2d_3b_1x1')
    x = conv2d_bn(x, 192, 3, padding='valid', name='Conv2d_4a_3x3')
    x = conv2d_bn(x, 256, 3, strides=2, padding='valid', name='Conv2d_4b_3x3')

    # 5x Block35 (Inception-ResNet-A block):
    for block_idx in range(1, 6):
        x = _inception_resnet_block(x,
                                    scale=0.17,
                                    block_type='Block35',
                                    block_idx=block_idx)

    # Mixed 6a (Reduction-A block):
    channel_axis = 1 if K.image_data_format() == 'channels_first' else 3
    name_fmt = partial(_generate_layer_name, prefix='Mixed_6a')
    branch_0 = conv2d_bn(x,
                         384,
                         3,
                         strides=2,
                         padding='valid',
                         name=name_fmt('Conv2d_1a_3x3', 0))
    branch_1 = conv2d_bn(x, 192, 1, name=name_fmt('Conv2d_0a_1x1', 1))
    branch_1 = conv2d_bn(branch_1, 192, 3, name=name_fmt('Conv2d_0b_3x3', 1))
    branch_1 = conv2d_bn(branch_1,
                         256,
                         3,
                         strides=2,
                         padding='valid',
                         name=name_fmt('Conv2d_1a_3x3', 1))
    branch_pool = MaxPooling2D(3,
                               strides=2,
                               padding='valid',
                               name=name_fmt('MaxPool_1a_3x3', 2))(x)
    branches = [branch_0, branch_1, branch_pool]
    x = Concatenate(axis=channel_axis, name='Mixed_6a')(branches)

    # 10x Block17 (Inception-ResNet-B block):
    for block_idx in range(1, 11):
        x = _inception_resnet_block(x,
                                    scale=0.1,
                                    block_type='Block17',
                                    block_idx=block_idx)

    # Mixed 7a (Reduction-B block): 8 x 8 x 2080
    name_fmt = partial(_generate_layer_name, prefix='Mixed_7a')
    branch_0 = conv2d_bn(x, 256, 1, name=name_fmt('Conv2d_0a_1x1', 0))
    branch_0 = conv2d_bn(branch_0,
                         384,
                         3,
                         strides=2,
                         padding='valid',
                         name=name_fmt('Conv2d_1a_3x3', 0))
    branch_1 = conv2d_bn(x, 256, 1, name=name_fmt('Conv2d_0a_1x1', 1))
    branch_1 = conv2d_bn(branch_1,
                         256,
                         3,
                         strides=2,
                         padding='valid',
                         name=name_fmt('Conv2d_1a_3x3', 1))
    branch_2 = conv2d_bn(x, 256, 1, name=name_fmt('Conv2d_0a_1x1', 2))
    branch_2 = conv2d_bn(branch_2, 256, 3, name=name_fmt('Conv2d_0b_3x3', 2))
    branch_2 = conv2d_bn(branch_2,
                         256,
                         3,
                         strides=2,
                         padding='valid',
                         name=name_fmt('Conv2d_1a_3x3', 2))
    branch_pool = MaxPooling2D(3,
                               strides=2,
                               padding='valid',
                               name=name_fmt('MaxPool_1a_3x3', 3))(x)
    branches = [branch_0, branch_1, branch_2, branch_pool]
    x = Concatenate(axis=channel_axis, name='Mixed_7a')(branches)

    # 5x Block8 (Inception-ResNet-C block):
    for block_idx in range(1, 6):
        x = _inception_resnet_block(x,
                                    scale=0.2,
                                    block_type='Block8',
                                    block_idx=block_idx)
    x = _inception_resnet_block(x,
                                scale=1.,
                                activation=None,
                                block_type='Block8',
                                block_idx=6)

    # Classification block
    x = GlobalAveragePooling2D(name='AvgPool')(x)
    x = Dropout(1.0 - dropout_keep_prob, name='Dropout')(x)
    # Bottleneck
    x = Dense(classes, use_bias=False, name='Bottleneck')(x)
    bn_name = _generate_layer_name('BatchNorm', prefix='Bottleneck')
    x = BatchNormalization(momentum=0.995, epsilon=0.001, scale=False,
                           name=bn_name)(x)

    # Create model
    model = Model(inputs, x, name='inception_resnet_v1')
    if weights_path is not None:
        model.load_weights(weights_path)

    return model

# %%
## FaceNet 구조 생성 코드
facenet_model = InceptionResNetV1()

# %%
## FaceNet 구조의 전체 레이어 길이
len(facenet_model.layers)
# Out:
# 447

# %%
## FaceNet 전체 구조 확인
facenet_model.summary()
# Out:
# Model: "inception_resnet_v1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 160, 160, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_1a_3x3 (Conv2D)    │ (None, 79, 79, 32)     │            864 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_1a_3x3_BatchNorm   │ (None, 79, 79, 32)     │             96 │ Conv2d_1a_3x3[0][0]    │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_1a_3x3_Activation  │ (None, 79, 79, 32)     │              0 │ Conv2d_1a_3x3_BatchNo… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_2a_3x3 (Conv2D)    │ (None, 77, 77, 32)     │          9,216 │ Conv2d_1a_3x3_Activat… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_2a_3x3_BatchNorm   │ (None, 77, 77, 32)     │             96 │ Conv2d_2a_3x3[0][0]    │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_2a_3x3_Activation  │ (None, 77, 77, 32)     │              0 │ Conv2d_2a_3x3_BatchNo… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_2b_3x3 (Conv2D)    │ (None, 77, 77, 64)     │         18,432 │ Conv2d_2a_3x3_Activat… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_2b_3x3_BatchNorm   │ (None, 77, 77, 64)     │            192 │ Conv2d_2b_3x3[0][0]    │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_2b_3x3_Activation  │ (None, 77, 77, 64)     │              0 │ Conv2d_2b_3x3_BatchNo… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ MaxPool_3a_3x3            │ (None, 38, 38, 64)     │              0 │ Conv2d_2b_3x3_Activat… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_3b_1x1 (Conv2D)    │ (None, 38, 38, 80)     │          5,120 │ MaxPool_3a_3x3[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_3b_1x1_BatchNorm   │ (None, 38, 38, 80)     │            240 │ Conv2d_3b_1x1[0][0]    │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_3b_1x1_Activation  │ (None, 38, 38, 80)     │              0 │ Conv2d_3b_1x1_BatchNo… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_4a_3x3 (Conv2D)    │ (None, 36, 36, 192)    │        138,240 │ Conv2d_3b_1x1_Activat… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_4a_3x3_BatchNorm   │ (None, 36, 36, 192)    │            576 │ Conv2d_4a_3x3[0][0]    │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_4a_3x3_Activation  │ (None, 36, 36, 192)    │              0 │ Conv2d_4a_3x3_BatchNo… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_4b_3x3 (Conv2D)    │ (None, 17, 17, 256)    │        442,368 │ Conv2d_4a_3x3_Activat… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_4b_3x3_BatchNorm   │ (None, 17, 17, 256)    │            768 │ Conv2d_4b_3x3[0][0]    │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv2d_4b_3x3_Activation  │ (None, 17, 17, 256)    │              0 │ Conv2d_4b_3x3_BatchNo… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Conv2d_4b_3x3_Activat… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_1_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_1_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_1_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Conv2d_4b_3x3_Activat… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_1_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_1_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_1_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_1_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_1_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_0_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Conv2d_4b_3x3_Activat… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_1_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_1_Branch_1_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_1_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_0_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_1_Branch_0_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_1_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_1_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_0_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_1_Branch_0_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_1_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_1_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Concatenate     │ (None, 17, 17, 96)     │              0 │ Block35_1_Branch_0_Co… │
# │ (Concatenate)             │                        │                │ Block35_1_Branch_1_Co… │
# │                           │                        │                │ Block35_1_Branch_2_Co… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Conv2d_1x1      │ (None, 17, 17, 256)    │         24,832 │ Block35_1_Concatenate… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda (Lambda)           │ (None, 17, 17, 256)    │              0 │ Block35_1_Conv2d_1x1[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add (Add)                 │ (None, 17, 17, 256)    │              0 │ Conv2d_4b_3x3_Activat… │
# │                           │                        │                │ lambda[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_1_Activation      │ (None, 17, 17, 256)    │              0 │ add[0][0]              │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_1_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_2_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_2_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_1_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_1_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_2_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_2_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_2_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_2_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_2_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_0_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_1_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_1_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_2_Branch_1_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_2_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_0_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_2_Branch_0_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_2_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_2_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_0_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_2_Branch_0_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_2_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_2_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Concatenate     │ (None, 17, 17, 96)     │              0 │ Block35_2_Branch_0_Co… │
# │ (Concatenate)             │                        │                │ Block35_2_Branch_1_Co… │
# │                           │                        │                │ Block35_2_Branch_2_Co… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Conv2d_1x1      │ (None, 17, 17, 256)    │         24,832 │ Block35_2_Concatenate… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_1 (Lambda)         │ (None, 17, 17, 256)    │              0 │ Block35_2_Conv2d_1x1[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_1 (Add)               │ (None, 17, 17, 256)    │              0 │ Block35_1_Activation[… │
# │                           │                        │                │ lambda_1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_2_Activation      │ (None, 17, 17, 256)    │              0 │ add_1[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_2_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_3_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_3_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_1_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_2_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_3_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_3_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_3_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_3_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_3_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_0_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_2_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_1_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_3_Branch_1_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_3_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_0_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_3_Branch_0_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_3_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_3_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_0_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_3_Branch_0_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_3_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_3_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Concatenate     │ (None, 17, 17, 96)     │              0 │ Block35_3_Branch_0_Co… │
# │ (Concatenate)             │                        │                │ Block35_3_Branch_1_Co… │
# │                           │                        │                │ Block35_3_Branch_2_Co… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Conv2d_1x1      │ (None, 17, 17, 256)    │         24,832 │ Block35_3_Concatenate… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_2 (Lambda)         │ (None, 17, 17, 256)    │              0 │ Block35_3_Conv2d_1x1[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_2 (Add)               │ (None, 17, 17, 256)    │              0 │ Block35_2_Activation[… │
# │                           │                        │                │ lambda_2[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_3_Activation      │ (None, 17, 17, 256)    │              0 │ add_2[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_3_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_4_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_4_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_1_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_3_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_4_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_4_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_4_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_4_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_4_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_0_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_3_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_1_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_4_Branch_1_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_4_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_0_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_4_Branch_0_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_4_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_4_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_0_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_4_Branch_0_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_4_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_4_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Concatenate     │ (None, 17, 17, 96)     │              0 │ Block35_4_Branch_0_Co… │
# │ (Concatenate)             │                        │                │ Block35_4_Branch_1_Co… │
# │                           │                        │                │ Block35_4_Branch_2_Co… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Conv2d_1x1      │ (None, 17, 17, 256)    │         24,832 │ Block35_4_Concatenate… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_3 (Lambda)         │ (None, 17, 17, 256)    │              0 │ Block35_4_Conv2d_1x1[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_3 (Add)               │ (None, 17, 17, 256)    │              0 │ Block35_3_Activation[… │
# │                           │                        │                │ lambda_3[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_4_Activation      │ (None, 17, 17, 256)    │              0 │ add_3[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_4_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_5_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_5_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_1_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_4_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_5_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_5_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_5_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_5_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_5_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_0_Conv2… │ (None, 17, 17, 32)     │          8,192 │ Block35_4_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_1_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_5_Branch_1_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │          9,216 │ Block35_5_Branch_2_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_0_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_5_Branch_0_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_1_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_5_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │             96 │ Block35_5_Branch_2_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_0_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_5_Branch_0_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_1_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_5_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Branch_2_Conv2… │ (None, 17, 17, 32)     │              0 │ Block35_5_Branch_2_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Concatenate     │ (None, 17, 17, 96)     │              0 │ Block35_5_Branch_0_Co… │
# │ (Concatenate)             │                        │                │ Block35_5_Branch_1_Co… │
# │                           │                        │                │ Block35_5_Branch_2_Co… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Conv2d_1x1      │ (None, 17, 17, 256)    │         24,832 │ Block35_5_Concatenate… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_4 (Lambda)         │ (None, 17, 17, 256)    │              0 │ Block35_5_Conv2d_1x1[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_4 (Add)               │ (None, 17, 17, 256)    │              0 │ Block35_4_Activation[… │
# │                           │                        │                │ lambda_4[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block35_5_Activation      │ (None, 17, 17, 256)    │              0 │ add_4[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 17, 17, 192)    │         49,152 │ Block35_5_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 17, 17, 192)    │            576 │ Mixed_6a_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 17, 17, 192)    │              0 │ Mixed_6a_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 17, 17, 192)    │        331,776 │ Mixed_6a_Branch_1_Con… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 17, 17, 192)    │            576 │ Mixed_6a_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 17, 17, 192)    │              0 │ Mixed_6a_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_0_Conv2d… │ (None, 8, 8, 384)      │        884,736 │ Block35_5_Activation[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 8, 8, 256)      │        442,368 │ Mixed_6a_Branch_1_Con… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_0_Conv2d… │ (None, 8, 8, 384)      │          1,152 │ Mixed_6a_Branch_0_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 8, 8, 256)      │            768 │ Mixed_6a_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_0_Conv2d… │ (None, 8, 8, 384)      │              0 │ Mixed_6a_Branch_0_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_1_Conv2d… │ (None, 8, 8, 256)      │              0 │ Mixed_6a_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a_Branch_2_MaxPoo… │ (None, 8, 8, 256)      │              0 │ Block35_5_Activation[… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Mixed_6a (Concatenate)    │ (None, 8, 8, 896)      │              0 │ Mixed_6a_Branch_0_Con… │
# │                           │                        │                │ Mixed_6a_Branch_1_Con… │
# │                           │                        │                │ Mixed_6a_Branch_2_Max… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │        114,688 │ Mixed_6a[0][0]         │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │            384 │ Block17_1_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │              0 │ Block17_1_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │        114,688 │ Block17_1_Branch_1_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │            384 │ Block17_1_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │              0 │ Block17_1_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_0_Conv2… │ (None, 8, 8, 128)      │        114,688 │ Mixed_6a[0][0]         │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │        114,688 │ Block17_1_Branch_1_Co… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_0_Conv2… │ (None, 8, 8, 128)      │            384 │ Block17_1_Branch_0_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │            384 │ Block17_1_Branch_1_Co… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_0_Conv2… │ (None, 8, 8, 128)      │              0 │ Block17_1_Branch_0_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Branch_1_Conv2… │ (None, 8, 8, 128)      │              0 │ Block17_1_Branch_1_Co… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Concatenate     │ (None, 8, 8, 256)      │              0 │ Block17_1_Branch_0_Co… │
# │ (Concatenate)             │                        │                │ Block17_1_Branch_1_Co… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Conv2d_1x1      │ (None, 8, 8, 896)      │        230,272 │ Block17_1_Concatenate… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_5 (Lambda)         │ (None, 8, 8, 896)      │              0 │ Block17_1_Conv2d_1x1[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_5 (Add)               │ (None, 8, 8, 896)      │              0 │ Mixed_6a[0][0],        │
# │                           │                        │                │ lambda_5[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block17_1_Activation      │ (None, 8, 8, 896)      │              0 │ add_5[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# ...
# │ add_17 (Add)              │ (None, 3, 3, 1792)     │              0 │ Block8_2_Activation[0… │
# │                           │                        │                │ lambda_17[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_3_Activation       │ (None, 3, 3, 1792)     │              0 │ add_17[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        344,064 │ Block8_3_Activation[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_4_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_4_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        110,592 │ Block8_4_Branch_1_Con… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_4_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_4_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_0_Conv2d… │ (None, 3, 3, 192)      │        344,064 │ Block8_3_Activation[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        110,592 │ Block8_4_Branch_1_Con… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_0_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_4_Branch_0_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_4_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_0_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_4_Branch_0_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_4_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Concatenate      │ (None, 3, 3, 384)      │              0 │ Block8_4_Branch_0_Con… │
# │ (Concatenate)             │                        │                │ Block8_4_Branch_1_Con… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Conv2d_1x1       │ (None, 3, 3, 1792)     │        689,920 │ Block8_4_Concatenate[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_18 (Lambda)        │ (None, 3, 3, 1792)     │              0 │ Block8_4_Conv2d_1x1[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_18 (Add)              │ (None, 3, 3, 1792)     │              0 │ Block8_3_Activation[0… │
# │                           │                        │                │ lambda_18[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_4_Activation       │ (None, 3, 3, 1792)     │              0 │ add_18[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        344,064 │ Block8_4_Activation[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_5_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_5_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        110,592 │ Block8_5_Branch_1_Con… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_5_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_5_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_0_Conv2d… │ (None, 3, 3, 192)      │        344,064 │ Block8_4_Activation[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        110,592 │ Block8_5_Branch_1_Con… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_0_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_5_Branch_0_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_5_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_0_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_5_Branch_0_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_5_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Concatenate      │ (None, 3, 3, 384)      │              0 │ Block8_5_Branch_0_Con… │
# │ (Concatenate)             │                        │                │ Block8_5_Branch_1_Con… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Conv2d_1x1       │ (None, 3, 3, 1792)     │        689,920 │ Block8_5_Concatenate[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_19 (Lambda)        │ (None, 3, 3, 1792)     │              0 │ Block8_5_Conv2d_1x1[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_19 (Add)              │ (None, 3, 3, 1792)     │              0 │ Block8_4_Activation[0… │
# │                           │                        │                │ lambda_19[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_5_Activation       │ (None, 3, 3, 1792)     │              0 │ add_19[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        344,064 │ Block8_5_Activation[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_6_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_6_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        110,592 │ Block8_6_Branch_1_Con… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_6_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_6_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_0_Conv2d… │ (None, 3, 3, 192)      │        344,064 │ Block8_5_Activation[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │        110,592 │ Block8_6_Branch_1_Con… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_0_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_6_Branch_0_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │            576 │ Block8_6_Branch_1_Con… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_0_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_6_Branch_0_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Branch_1_Conv2d… │ (None, 3, 3, 192)      │              0 │ Block8_6_Branch_1_Con… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Concatenate      │ (None, 3, 3, 384)      │              0 │ Block8_6_Branch_0_Con… │
# │ (Concatenate)             │                        │                │ Block8_6_Branch_1_Con… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Block8_6_Conv2d_1x1       │ (None, 3, 3, 1792)     │        689,920 │ Block8_6_Concatenate[… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_20 (Lambda)        │ (None, 3, 3, 1792)     │              0 │ Block8_6_Conv2d_1x1[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_20 (Add)              │ (None, 3, 3, 1792)     │              0 │ Block8_5_Activation[0… │
# │                           │                        │                │ lambda_20[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ AvgPool                   │ (None, 1792)           │              0 │ add_20[0][0]           │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Dropout (Dropout)         │ (None, 1792)           │              0 │ AvgPool[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Bottleneck (Dense)        │ (None, 128)            │        229,376 │ Dropout[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Bottleneck_BatchNorm      │ (None, 128)            │            384 │ Bottleneck[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 22,808,144 (87.01 MB)
#  Trainable params: 22,779,312 (86.90 MB)
#  Non-trainable params: 28,832 (112.62 KB)

# %% [markdown]
# #### 2) 모델에 가중치 적용

# %%
## FaceNet 가중치 파일 경로 설정
weights_path = os.path.join(path, 'Datasets/Keras/facenet_model_weights.npz')
weights_path
# Out:
# '/content/drive/MyDrive/project4/Datasets/Keras/facenet_model_weights.npz'

# %%
## 가중치 파일 불러오기
loaded_weights = np.load(weights_path)

loaded_weights
# Out:
# NpzFile '/content/drive/MyDrive/project4/Datasets/Keras/facenet_model_weights.npz' with keys: arr_0, arr_1, arr_2, arr_3, arr_4...

# %%
## FaceNet 각 레이어에 가중치 적용
facenet_model.set_weights([loaded_weights[key] for key in loaded_weights])

# %% [markdown]
# #### 3) 모델의 가중치 업데이트 방지 (선택사항)

# %%
## FaceNet 전체 레이어에서 마지막 4개의 레이어 확인
facenet_model.layers[-4:]
# Out:
# [<GlobalAveragePooling2D name=AvgPool, built=True>,
#  <Dropout name=Dropout, built=True>,
#  <Dense name=Bottleneck, built=True>,
#  <BatchNormalization name=Bottleneck_BatchNorm, built=True>]

# %%
## FaceNet 전체 레이어에서 마지막 4개의 레이어에만 가중치 업데이트 적용
for l in facenet_model.layers[:-4] :
    l.trainable = False

# %% [markdown]
# ### (2) 모델 구조 변형

# %% [markdown]
# * **세부 요구사항**
#     - 우리의 문제에 맞게 모델을 변형해야 합니다.
#     - 예시 코드에서 사용한 라이브러리
#         - keras

# %% [markdown]
# #### 1) 추가 모델링

# %%
## FaceNet 모델에 이진 분류용 레이어 하나 추가
K.clear_session()

custom_model = keras.models.Sequential()

custom_model.add(facenet_model)
custom_model.add(Dense(1, activation='sigmoid') )

# %%
custom_model.summary() ## keras-nightly로는 정상 작동
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ inception_resnet_v1 (Functional)     │ (None, 128)                 │      22,808,144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 22,808,273 (87.01 MB)
#  Trainable params: 229,633 (897.00 KB)
#  Non-trainable params: 22,578,640 (86.13 MB)

# %%
custom_model.compile(optimizer='adam',
                     loss='binary_crossentropy',
                     metrics=['accuracy', 'precision', 'recall']
                     )

# %% [markdown]
# ## 5.미션3

# %% [markdown]
# 학습된 모델로 추론하여 성능 지표를 확인하고 모델을 개선시키세요.
#
# 그 후, 모델의 구조와 가중치를 **반드시 저장**하여 여러분의 노트북에 옮기세요.
#
# - 1) 다양한 모델을 사용해보세요.
#     - 모델에 정해진 정답은 없습니다.
#     - 성능 지표에서 무엇이 중요한지 깊게 생각하세요.
#     - 사전 학습된 FaceNet 모델을 사용하셔도 좋고, 아예 독창적으로 여러분만의 모델을 만드셔도 좋습니다!
# - 2) 모델을 **반드시 저장**하세요.
#     - .keras 형태로 우선 Colab에 저장하세요.
#     - Colab에 생성된 .keras 파일을 **로컬에 다운로드** 합니다.

# %% [markdown]
# ### (1) 모델 학습

# %% [markdown]
# * **세부 요구사항**
#     - 모델 구조를 잘 변형하였다면, 학습도 진행해야 합니다.
#         - Keras에서 지원하는 다양한 함수를 사용하세요.
#     - 예시 코드에서 사용한 라이브러리
#         - keras

# %% [markdown]
# #### 1) 학습에 유용한 함수 불러오기

# %%
from keras.callbacks import EarlyStopping

# %%
## 얼리스토핑 설정
es = EarlyStopping(patience=4, verbose=1, restore_best_weights=True)

# %% [markdown]
# #### 2) 모델 학습

# %%
## 모델 학습
custom_model.fit(tr_idfd, validation_data=val_idfd,
                 epochs=100, verbose=1,
                 class_weight={0:1, 1:2}, ## 클래스 1에 대해 가중치를 더 주려는 의도
                 callbacks=[es]
                 )
# Out:
# Epoch 1/100
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 67s 131ms/step - accuracy: 0.9431 - loss: 0.1464 - precision: 0.8790 - recall: 0.9836 - val_accuracy: 1.0000 - val_loss: 0.0036 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 2/100
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 49s 61ms/step - accuracy: 0.9958 - loss: 0.0176 - precision: 0.9892 - recall: 0.9990 - val_accuracy: 0.9998 - val_loss: 0.0029 - val_precision: 0.9994 - val_recall: 1.0000
# Epoch 3/100
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 26s 74ms/step - accuracy: 0.9956 - loss: 0.0158 - precision: 0.9892 - recall: 0.9983 - val_accuracy: 0.9992 - val_loss: 0.0029 - val_precision: 0.9976 - val_recall: 1.0000
# Epoch 4/100
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 26s 74ms/step - accuracy: 0.9978 - loss: 0.0090 - precision: 0.9949 - recall: 0.9988 - val_accuracy: 0.9998 - val_loss: 4.9031e-04 - val_precision: 1.0000 - val_recall: 0.9994
# Epoch 5/100
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 40s 70ms/step - accuracy: 0.9973 - loss: 0.0068 - precision: 0.9931 - recall: 0.9992 - val_accuracy: 0.9998 - val_loss: 0.0018 - val_precision: 0.9994 - val_recall: 1.0000
# Epoch 6/100
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 22s 62ms/step - accuracy: 0.9981 - loss: 0.0061 - precision: 0.9949 - recall: 0.9996 - val_accuracy: 1.0000 - val_loss: 2.9365e-04 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 7/100
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 40s 60ms/step - accuracy: 0.9982 - loss: 0.0074 - precision: 0.9965 - recall: 0.9985 - val_accuracy: 1.0000 - val_loss: 1.2012e-04 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 8/100
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 26s 74ms/step - accuracy: 0.9976 - loss: 0.0071 - precision: 0.9949 - recall: 0.9983 - val_accuracy: 1.0000 - val_loss: 4.4711e-05 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 9/100
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 21s 59ms/step - accuracy: 0.9977 - loss: 0.0071 - precision: 0.9951 - recall: 0.9983 - val_accuracy: 1.0000 - val_loss: 7.5717e-05 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 10/100
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 26s 73ms/step - accuracy: 0.9987 - loss: 0.0068 - precision: 0.9979 - recall: 0.9983 - val_accuracy: 1.0000 - val_loss: 2.8066e-04 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 11/100
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 41s 74ms/step - accuracy: 0.9984 - loss: 0.0078 - precision: 0.9969 - recall: 0.9987 - val_accuracy: 1.0000 - val_loss: 8.8606e-05 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 12/100
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 40s 72ms/step - accuracy: 0.9987 - loss: 0.0055 - precision: 0.9973 - recall: 0.9990 - val_accuracy: 1.0000 - val_loss: 4.9789e-05 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 8.

# %% [markdown]
# ### (2) 모델 추론

# %% [markdown]
# * **세부 요구사항**
#     - 학습된 모델의 성능을 확인해보세요.
#         - 임계값 조절, 클래스 가중치 부여 등으로 모델의 성능을 높여보세요.
#     - 예시 코드에서 사용한 라이브러리
#         - keras, sklearn

# %% [markdown]
# #### 1) 모델 추론

# %%
## image_dataset_from_directory로 만든 Test set로 예측값 생성
y_pred = custom_model.predict(te_idfd)
y_pred
# Out:
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 21s 111ms/step
# array([[5.3894462e-11],
#        [9.9999976e-01],
#        [1.0000000e+00],
#        ...,
#        [1.3556080e-09],
#        [2.3014003e-10],
#        [1.6370505e-07]], dtype=float32)

# %%
## 예측값에 대한 임계값을 0.5로 설정하여 0과 1로 구분
y_pred_fix = np.where(y_pred>=0.5, 1, 0)
y_pred_fix = y_pred_fix.flatten()
y_pred_fix
# Out:
# array([0, 1, 1, ..., 0, 0, 0])

# %%
len(y_pred_fix.nonzero()[0])
# Out:
# 1400

# %% [markdown]
# #### 2) 성능 확인

# %%
from sklearn.metrics import classification_report

# %%
## 성능 확인을 위하여 Test set의 Y만 떼와 array로 저장
temp = []

for te_x, te_y in te_idfd :
    temp.append(te_y.numpy())

y_true = np.concatenate(temp)

# %%
len(y_true.nonzero()[0])
# Out:
# 1400

# %%
print(classification_report(y_true, y_pred_fix, target_names=['other', 'my']) )
# Out:
#               precision    recall  f1-score   support
#
#        other       0.66      0.66      0.66      2647
#           my       0.35      0.35      0.35      1400
#
#     accuracy                           0.55      4047
#    macro avg       0.50      0.50      0.50      4047
# weighted avg       0.55      0.55      0.55      4047

# %% [markdown]
# --추가

# %% [markdown]
# ### (3) 모델 저장

# %% [markdown]
# * **세부 요구사항**
#     - **반드시 반드시 모델을 저장하고 로컬에 다운로드하세요.**
#     - 예시 코드에서 사용한 라이브러리
#         - keras

# %% [markdown]
# #### 1) 모델 저장

# %%
## .keras로 저장해야 안전
# 모델을 .keras 파일로 저장
custom_model.save("custom_model_final.keras")

# %% [markdown]
# #### 2) 저장된 모델 체크

# %%
## Colab에 저장된 모델을 불러와 확인
temp_model = keras.saving.load_model("custom_model_final.keras")
temp_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ inception_resnet_v1 (Functional)     │ (None, 128)                 │      22,808,144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 23,267,541 (88.76 MB)
#  Trainable params: 229,633 (897.00 KB)
#  Non-trainable params: 22,578,640 (86.13 MB)
#  Optimizer params: 459,268 (1.75 MB)
